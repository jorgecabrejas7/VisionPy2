# %%
import tifffile as t
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import zarr
from matplotlib.widgets import Slider
import dask.array as da
import dask
import timeit
import matplotlib

matplotlib.use("QtAgg")

# %%
def imshow(volume):
    # Initialize plot.
    fig, ax = plt.subplots()
    plt.subplots_adjust(left=0.25, bottom=0.25)

    # Assuming volume is a zarr array and we're slicing along the first axis.
    slice_idx = volume.shape[0] // 2  # Start in the middle of the volume
    img = ax.imshow(volume[slice_idx, :, :], cmap="gray")

    # Position of the slider
    ax_slider = plt.axes([0.25, 0.1, 0.65, 0.03])

    # Slider properties
    slider = Slider(
        ax=ax_slider,
        label="Slice",
        valmin=0,
        valmax=volume.shape[0] - 1,
        valinit=slice_idx,
        valstep=1,
    )

    # Update function for the slider
    def update(val):
        slice_idx = int(slider.val)
        img.set_data(volume[slice_idx, :, :])
        fig.canvas.draw_idle()

    # Call update function on slider value change
    slider.on_changed(update)

    # Function to handle keyboard input (left and right arrow keys)
    def on_key(event):
        if event.key == "left":
            new_val = max(slider.val - 1, slider.valmin)  # Decrease slider value
        elif event.key == "right":
            new_val = min(slider.val + 1, slider.valmax)  # Increase slider value
        else:
            return
        slider.set_val(new_val)  # Update the slider value

    # Connect the keyboard event to the on_key function
    fig.canvas.mpl_connect("key_press_event", on_key)

    plt.show()


def interactive_slice_viewer(volume, axis=0):
    # Crop the volume
    # Retain all slices and height, take 1/100th of the width
    cropped_volume = volume[:, :, : volume.shape[2] // 100]

    # Initialize plot.
    fig, ax = plt.subplots()
    plt.subplots_adjust(left=0.25, bottom=0.25)

    # Set initial slice index (middle of the volume along the specified axis)
    slice_idx = cropped_volume.shape[axis] // 2

    # Function to get the slice based on the axis
    def get_slice(idx):
        if axis == 0:
            return cropped_volume[idx, :, :]
        elif axis == 1:
            return cropped_volume[:, idx, :]
        elif axis == 2:
            return cropped_volume[:, :, idx]
        else:
            raise ValueError("Invalid axis. Axis must be 0, 1, or 2.")

    # Display initial slice
    img = ax.imshow(get_slice(slice_idx), cmap="gray", origin="lower")

    # Create slider for navigating slices
    ax_slider = plt.axes([0.25, 0.1, 0.65, 0.03])
    slider = Slider(
        ax=ax_slider,
        label="Slice",
        valmin=0,
        valmax=cropped_volume.shape[axis] - 1,
        valinit=slice_idx,
        valstep=1,
    )

    # Update function for the slider
    def update(val):
        idx = int(slider.val)
        img.set_data(get_slice(idx))
        fig.canvas.draw_idle()

    slider.on_changed(update)

    # Keyboard controls for slider
    def on_key(event):
        if event.key == "left":
            new_val = max(slider.val - 1, slider.valmin)
        elif event.key == "right":
            new_val = min(slider.val + 1, slider.valmax)
        else:
            return
        slider.set_val(new_val)

    fig.canvas.mpl_connect("key_press_event", on_key)

    plt.show()


def interactive_slice_viewer_dask(dask_volume, axis=0):
    # Initialize plot.
    fig, ax = plt.subplots()
    plt.subplots_adjust(left=0.25, bottom=0.25)

    # Set initial slice index (middle of the volume along the specified axis)
    slice_idx = dask_volume.shape[axis] // 2

    # Function to get the slice based on the axis
    def get_slice(idx):
        if axis == 0:
            return dask_volume[idx, :, :].compute()  # Compute the slice
        elif axis == 1:
            return dask_volume[:, idx, :].compute()  # Compute the slice
        elif axis == 2:
            return dask_volume[:, :, idx].compute()  # Compute the slice
        else:
            raise ValueError("Invalid axis. Axis must be 0, 1, or 2.")

    # Display initial slice
    img = ax.imshow(get_slice(slice_idx), cmap="gray", origin="lower")

    # Create slider for navigating slices
    ax_slider = plt.axes([0.25, 0.1, 0.65, 0.03])
    slider = Slider(
        ax=ax_slider,
        label="Slice",
        valmin=0,
        valmax=dask_volume.shape[axis] - 1,
        valinit=slice_idx,
        valstep=1,
    )

    # Update function for the slider
    def update(val):
        idx = int(slider.val)
        img.set_data(get_slice(idx))
        fig.canvas.draw_idle()

    slider.on_changed(update)

    # Keyboard controls for slider
    def on_key(event):
        if event.key == "left":
            new_val = max(slider.val - 1, slider.valmin)
        elif event.key == "right":
            new_val = min(slider.val + 1, slider.valmax)
        else:
            return
        slider.set_val(new_val)

    fig.canvas.mpl_connect("key_press_event", on_key)

    plt.show()

def create_figure():
    plt.ion()  # Turn on interactive mode
    fig, ax = plt.subplots()
    def on_close(event):
        plt.ioff()  # Turn off interactive mode
        plt.close(event.canvas.figure)  # Close the figure
    fig.canvas.mpl_connect('close_event', on_close)
    return fig, ax

# %%
seq = t.TiffSequence(
    "Ti-5Fe_05_Ti64_350W_700mmpmin_2p4gpmin_layer-01_S0001_S0001/*.tif",
)


vol = zarr.open(seq.aszarr())
partial_vol = np.load("partial_vol.npy")
right_side = np.transpose(partial_vol, (2, 1, 0))

# %%
fig, ax = create_figure()
ax.imshow(right_side[0], cmap="gray", origin="lower")
plt.show()

# %%
# Select a slice from 'right_side' volume
slice_idx = 50  # Change as needed
original_slice = right_side[slice_idx]

# Resize only the width (x-axis) of the slice for visualization

resized_slice = original_slice[:, ::100]

# %%
fig, ax = create_figure()
ax.imshow(resized_slice, cmap='gray')
line_coords_resized = []

def on_click(event):
    if fig.canvas.toolbar.mode == '':
        # Store the x and y coordinates of the click event in the resized space
        line_coords_resized.append((event.xdata, event.ydata))
        if len(line_coords_resized) == 2:
            ax.plot([line_coords_resized[0][0], line_coords_resized[1][0]], [line_coords_resized[0][1], line_coords_resized[1][1]], 'r-')
            fig.canvas.draw()
            fig.canvas.mpl_disconnect(cid)

cid = fig.canvas.mpl_connect('button_press_event', on_click)
plt.show()

# %%
if len(line_coords_resized) == 2:
    # Map only the x-coordinates back to the original image space
    line_coords_original = [
        (0, line_coords_resized[0][1]),
        (original_slice.shape[1], line_coords_resized[1][1])
    ]
    print(f"Line in resized image space: {line_coords_resized}")
    print(f"Line in original image space: {line_coords_original}")
# Out:
# Line in resized image space: [(-0.2903711854544859, 440.01128091992433), (894.2203414507134, 500.448211950278)]
# Line in original image space: [(0, 440.01128091992433), (89470, 500.448211950278)]

# %%
import matplotlib.pyplot as plt

# Plot the original slice
fig, ax = create_figure()
ax.imshow(original_slice, cmap='gray')  # Display the original slice

# Draw the line on the original slice
# Extract x and y coordinates for the start and end points of the line
x_coords = [line_coords_original[0][0], line_coords_original[1][0]]
y_coords = [line_coords_original[0][1], line_coords_original[1][1]]

# Plot the line on the original image
ax.plot(x_coords, y_coords, 'r-')  # 'r-' means red line

# Display the plot with the line
plt.title("Original Slice with Converted Line")
plt.show()


"""
We can calculate each slice shift upwards or downwards by calculating the chord at the radius (slice).
To know the direction of the shift, we have to check if the line given by the user is above or below the horizontal line.
The horizontal line must be drawn from the first point (0, py) to (width, py) where py is the y-coordinate of the first point.
Then get the angle in absolute value between the horizontal line and the line given by the user and calculate each cord.
Check if this can be done like that, we must probably have to change behaviour to process one slice at a time.
Dask is becoming more neccessary with this approach, it may be useful to instead of save to disk perform the operations
concurrently with dask and assign back to the zarr array, reading it in write mode.
"""
# Out:
# '\nWe can calculate each slice shift upwards or downwards by calculating the chord at the radius (slice).\nTo know the direction of the shift, we have to check if the line given by the user is above or below the horizontal line.\nThe horizontal line must be drawn from the first point (0, py) to (width, py) where py is the y-coordinate of the first point.\nThen get the angle in absolute value between the horizontal line and the line given by the user and calculate each cord.\nCheck if this can be done like that, we must probably have to change behaviour to process one slice at a time.\nDask is becoming more neccessary with this approach, it may be useful to instead of save to disk perform the operations\nconcurrently with dask and assign back to the zarr array, reading it in write mode.\n'

# %%
dx = line_coords_original[1][0] - line_coords_original[0][0]
dy = line_coords_original[1][1] - line_coords_original[0][1]

# Calculate the angle in radians
angle_radians = np.arctan2(dy, dx)

# Convert the angle to degrees
angle_degrees = np.degrees(angle_radians)

# Determine the direction of the line
direction = "upwards" if dy < 0 else "downwards" if dy > 0 else "horizontal"


print(f"Angle (in radians): {angle_radians}")
print(f"Angle (in degrees): {angle_degrees}")
print(f"Direction of the line: {direction}")
print(f"{line_coords_original[0]} -> {line_coords_original[1]}")
# Same as above but with resized coordinates
print(f"{line_coords_resized[0]} -> {line_coords_resized[1]}")
# Out:
# Angle (in radians): 0.0006754992940416939
# Angle (in degrees): 0.03870325861265565
# Direction of the line: downwards
# (0, 440.01128091992433) -> (89470, 500.448211950278)
# (-0.2903711854544859, 440.01128091992433) -> (894.2203414507134, 500.448211950278)

# %%
import math
from concurrent.futures import ThreadPoolExecutor

iterator = range(vol.shape[0]) if direction == "downwards" else reversed(range(vol.shape[0]))
for i in iterator:
    # Slice the volume
    _slice = vol[i, :, :]
    shift_size = math.ceil(2 * i * math.sin(angle_radians / 2))
    print(f"Shifting slice {i} by {shift_size} pixels")
    shifted_slice = np.roll(_slice, -shift_size, axis=0)
    t.imwrite(f"./shifted/shifted_slice_{i}.tif", shifted_slice)
# Out:
# Shifting slice 0 by 0 pixels
# Shifting slice 1 by 1 pixels
# Shifting slice 2 by 1 pixels
# Shifting slice 3 by 1 pixels
# Shifting slice 4 by 1 pixels
# Shifting slice 5 by 1 pixels
# Shifting slice 6 by 1 pixels
# Shifting slice 7 by 1 pixels
# Shifting slice 8 by 1 pixels
# Shifting slice 9 by 1 pixels
# Shifting slice 10 by 1 pixels
# Shifting slice 11 by 1 pixels
# Shifting slice 12 by 1 pixels
# Shifting slice 13 by 1 pixels
# Shifting slice 14 by 1 pixels
# Shifting slice 15 by 1 pixels
# Shifting slice 16 by 1 pixels
# Shifting slice 17 by 1 pixels
# Shifting slice 18 by 1 pixels
# Shifting slice 19 by 1 pixels
# Shifting slice 20 by 1 pixels
# Shifting slice 21 by 1 pixels
# Shifting slice 22 by 1 pixels
# Shifting slice 23 by 1 pixels
# Shifting slice 24 by 1 pixels
# Shifting slice 25 by 1 pixels
# Shifting slice 26 by 1 pixels
# Shifting slice 27 by 1 pixels
# Shifting slice 28 by 1 pixels
# Shifting slice 29 by 1 pixels
# Shifting slice 30 by 1 pixels
# Shifting slice 31 by 1 pixels
# Shifting slice 32 by 1 pixels
# Shifting slice 33 by 1 pixels
# Shifting slice 34 by 1 pixels
# Shifting slice 35 by 1 pixels
# Shifting slice 36 by 1 pixels
# Shifting slice 37 by 1 pixels
# Shifting slice 38 by 1 pixels
# Shifting slice 39 by 1 pixels
# Shifting slice 40 by 1 pixels
# Shifting slice 41 by 1 pixels
# Shifting slice 42 by 1 pixels
# Shifting slice 43 by 1 pixels
# Shifting slice 44 by 1 pixels
# Shifting slice 45 by 1 pixels
# Shifting slice 46 by 1 pixels
# Shifting slice 47 by 1 pixels
# Shifting slice 48 by 1 pixels
# Shifting slice 49 by 1 pixels
# Shifting slice 50 by 1 pixels
# Shifting slice 51 by 1 pixels
# Shifting slice 52 by 1 pixels
# Shifting slice 53 by 1 pixels
# Shifting slice 54 by 1 pixels
# Shifting slice 55 by 1 pixels
# Shifting slice 56 by 1 pixels
# Shifting slice 57 by 1 pixels
# Shifting slice 58 by 1 pixels
# Shifting slice 59 by 1 pixels
# Shifting slice 60 by 1 pixels
# Shifting slice 61 by 1 pixels
# Shifting slice 62 by 1 pixels
# Shifting slice 63 by 1 pixels
# Shifting slice 64 by 1 pixels
# Shifting slice 65 by 1 pixels
# Shifting slice 66 by 1 pixels
# Shifting slice 67 by 1 pixels
# Shifting slice 68 by 1 pixels
# Shifting slice 69 by 1 pixels
# Shifting slice 70 by 1 pixels
# Shifting slice 71 by 1 pixels
# Shifting slice 72 by 1 pixels
# Shifting slice 73 by 1 pixels
# Shifting slice 74 by 1 pixels
# Shifting slice 75 by 1 pixels
# Shifting slice 76 by 1 pixels
# Shifting slice 77 by 1 pixels
# Shifting slice 78 by 1 pixels
# Shifting slice 79 by 1 pixels
# Shifting slice 80 by 1 pixels
# Shifting slice 81 by 1 pixels
# Shifting slice 82 by 1 pixels
# Shifting slice 83 by 1 pixels
# Shifting slice 84 by 1 pixels
# Shifting slice 85 by 1 pixels
# Shifting slice 86 by 1 pixels
# Shifting slice 87 by 1 pixels
# Shifting slice 88 by 1 pixels
# Shifting slice 89 by 1 pixels
# Shifting slice 90 by 1 pixels
# Shifting slice 91 by 1 pixels
# Shifting slice 92 by 1 pixels
# Shifting slice 93 by 1 pixels
# Shifting slice 94 by 1 pixels
# Shifting slice 95 by 1 pixels
# Shifting slice 96 by 1 pixels
# Shifting slice 97 by 1 pixels
# Shifting slice 98 by 1 pixels
# Shifting slice 99 by 1 pixels
# Shifting slice 100 by 1 pixels
# Shifting slice 101 by 1 pixels
# Shifting slice 102 by 1 pixels
# Shifting slice 103 by 1 pixels
# Shifting slice 104 by 1 pixels
# Shifting slice 105 by 1 pixels
# Shifting slice 106 by 1 pixels
# Shifting slice 107 by 1 pixels
# Shifting slice 108 by 1 pixels
# Shifting slice 109 by 1 pixels
# Shifting slice 110 by 1 pixels
# Shifting slice 111 by 1 pixels
# Shifting slice 112 by 1 pixels
# Shifting slice 113 by 1 pixels
# Shifting slice 114 by 1 pixels
# Shifting slice 115 by 1 pixels
# Shifting slice 116 by 1 pixels
# Shifting slice 117 by 1 pixels
# Shifting slice 118 by 1 pixels
# Shifting slice 119 by 1 pixels
# Shifting slice 120 by 1 pixels
# Shifting slice 121 by 1 pixels
# Shifting slice 122 by 1 pixels
# Shifting slice 123 by 1 pixels
# Shifting slice 124 by 1 pixels
# Shifting slice 125 by 1 pixels
# Shifting slice 126 by 1 pixels
# Shifting slice 127 by 1 pixels
# Shifting slice 128 by 1 pixels
# Shifting slice 129 by 1 pixels
# Shifting slice 130 by 1 pixels
# Shifting slice 131 by 1 pixels
# Shifting slice 132 by 1 pixels
# Shifting slice 133 by 1 pixels
# Shifting slice 134 by 1 pixels
# Shifting slice 135 by 1 pixels
# Shifting slice 136 by 1 pixels
# Shifting slice 137 by 1 pixels
# Shifting slice 138 by 1 pixels
# Shifting slice 139 by 1 pixels
# Shifting slice 140 by 1 pixels
# Shifting slice 141 by 1 pixels
# Shifting slice 142 by 1 pixels
# Shifting slice 143 by 1 pixels
# Shifting slice 144 by 1 pixels
# Shifting slice 145 by 1 pixels
# Shifting slice 146 by 1 pixels
# Shifting slice 147 by 1 pixels
# Shifting slice 148 by 1 pixels
# Shifting slice 149 by 1 pixels
# Shifting slice 150 by 1 pixels
# Shifting slice 151 by 1 pixels
# Shifting slice 152 by 1 pixels
# Shifting slice 153 by 1 pixels
# Shifting slice 154 by 1 pixels
# Shifting slice 155 by 1 pixels
# Shifting slice 156 by 1 pixels
# Shifting slice 157 by 1 pixels
# Shifting slice 158 by 1 pixels
# Shifting slice 159 by 1 pixels
# Shifting slice 160 by 1 pixels
# Shifting slice 161 by 1 pixels
# Shifting slice 162 by 1 pixels
# Shifting slice 163 by 1 pixels
# Shifting slice 164 by 1 pixels
# Shifting slice 165 by 1 pixels
# Shifting slice 166 by 1 pixels
# Shifting slice 167 by 1 pixels
# Shifting slice 168 by 1 pixels
# Shifting slice 169 by 1 pixels
# Shifting slice 170 by 1 pixels
# Shifting slice 171 by 1 pixels
# Shifting slice 172 by 1 pixels
# Shifting slice 173 by 1 pixels
# Shifting slice 174 by 1 pixels
# Shifting slice 175 by 1 pixels
# Shifting slice 176 by 1 pixels
# Shifting slice 177 by 1 pixels
# Shifting slice 178 by 1 pixels
# Shifting slice 179 by 1 pixels
# Shifting slice 180 by 1 pixels
# Shifting slice 181 by 1 pixels
# Shifting slice 182 by 1 pixels
# Shifting slice 183 by 1 pixels
# Shifting slice 184 by 1 pixels
# Shifting slice 185 by 1 pixels
# Shifting slice 186 by 1 pixels
# Shifting slice 187 by 1 pixels
# Shifting slice 188 by 1 pixels
# Shifting slice 189 by 1 pixels
# Shifting slice 190 by 1 pixels
# Shifting slice 191 by 1 pixels
# Shifting slice 192 by 1 pixels
# Shifting slice 193 by 1 pixels
# Shifting slice 194 by 1 pixels
# Shifting slice 195 by 1 pixels
# Shifting slice 196 by 1 pixels
# Shifting slice 197 by 1 pixels
# Shifting slice 198 by 1 pixels
# Shifting slice 199 by 1 pixels
# Shifting slice 200 by 1 pixels
# Shifting slice 201 by 1 pixels
# Shifting slice 202 by 1 pixels
# Shifting slice 203 by 1 pixels
# Shifting slice 204 by 1 pixels
# Shifting slice 205 by 1 pixels
# Shifting slice 206 by 1 pixels
# Shifting slice 207 by 1 pixels
# Shifting slice 208 by 1 pixels
# Shifting slice 209 by 1 pixels
# Shifting slice 210 by 1 pixels
# Shifting slice 211 by 1 pixels
# Shifting slice 212 by 1 pixels
# Shifting slice 213 by 1 pixels
# Shifting slice 214 by 1 pixels
# Shifting slice 215 by 1 pixels
# Shifting slice 216 by 1 pixels
# Shifting slice 217 by 1 pixels
# Shifting slice 218 by 1 pixels
# Shifting slice 219 by 1 pixels
# Shifting slice 220 by 1 pixels
# Shifting slice 221 by 1 pixels
# Shifting slice 222 by 1 pixels
# Shifting slice 223 by 1 pixels
# Shifting slice 224 by 1 pixels
# Shifting slice 225 by 1 pixels
# Shifting slice 226 by 1 pixels
# Shifting slice 227 by 1 pixels
# Shifting slice 228 by 1 pixels
# Shifting slice 229 by 1 pixels
# Shifting slice 230 by 1 pixels
# Shifting slice 231 by 1 pixels
# Shifting slice 232 by 1 pixels
# Shifting slice 233 by 1 pixels
# Shifting slice 234 by 1 pixels
# Shifting slice 235 by 1 pixels
# Shifting slice 236 by 1 pixels
# Shifting slice 237 by 1 pixels
# Shifting slice 238 by 1 pixels
# Shifting slice 239 by 1 pixels
# Shifting slice 240 by 1 pixels
# Shifting slice 241 by 1 pixels
# Shifting slice 242 by 1 pixels
# Shifting slice 243 by 1 pixels
# Shifting slice 244 by 1 pixels
# Shifting slice 245 by 1 pixels
# Shifting slice 246 by 1 pixels
# Shifting slice 247 by 1 pixels
# Shifting slice 248 by 1 pixels
# Shifting slice 249 by 1 pixels
# Shifting slice 250 by 1 pixels
# Shifting slice 251 by 1 pixels
# Shifting slice 252 by 1 pixels
# Shifting slice 253 by 1 pixels
# Shifting slice 254 by 1 pixels
# Shifting slice 255 by 1 pixels
# Shifting slice 256 by 1 pixels
# Shifting slice 257 by 1 pixels
# Shifting slice 258 by 1 pixels
# Shifting slice 259 by 1 pixels
# Shifting slice 260 by 1 pixels
# Shifting slice 261 by 1 pixels
# Shifting slice 262 by 1 pixels
# Shifting slice 263 by 1 pixels
# Shifting slice 264 by 1 pixels
# Shifting slice 265 by 1 pixels
# Shifting slice 266 by 1 pixels
# Shifting slice 267 by 1 pixels
# Shifting slice 268 by 1 pixels
# Shifting slice 269 by 1 pixels
# Shifting slice 270 by 1 pixels
# Shifting slice 271 by 1 pixels
# Shifting slice 272 by 1 pixels
# Shifting slice 273 by 1 pixels
# Shifting slice 274 by 1 pixels
# Shifting slice 275 by 1 pixels
# Shifting slice 276 by 1 pixels
# Shifting slice 277 by 1 pixels
# Shifting slice 278 by 1 pixels
# Shifting slice 279 by 1 pixels
# Shifting slice 280 by 1 pixels
# Shifting slice 281 by 1 pixels
# Shifting slice 282 by 1 pixels
# Shifting slice 283 by 1 pixels
# Shifting slice 284 by 1 pixels
# Shifting slice 285 by 1 pixels
# Shifting slice 286 by 1 pixels
# Shifting slice 287 by 1 pixels
# Shifting slice 288 by 1 pixels
# Shifting slice 289 by 1 pixels
# Shifting slice 290 by 1 pixels
# Shifting slice 291 by 1 pixels
# Shifting slice 292 by 1 pixels
# Shifting slice 293 by 1 pixels
# Shifting slice 294 by 1 pixels
# Shifting slice 295 by 1 pixels
# Shifting slice 296 by 1 pixels
# Shifting slice 297 by 1 pixels
# Shifting slice 298 by 1 pixels
# Shifting slice 299 by 1 pixels
# Shifting slice 300 by 1 pixels
# Shifting slice 301 by 1 pixels
# Shifting slice 302 by 1 pixels
# Shifting slice 303 by 1 pixels
# Shifting slice 304 by 1 pixels
# Shifting slice 305 by 1 pixels
# Shifting slice 306 by 1 pixels
# Shifting slice 307 by 1 pixels
# Shifting slice 308 by 1 pixels
# Shifting slice 309 by 1 pixels
# Shifting slice 310 by 1 pixels
# Shifting slice 311 by 1 pixels
# Shifting slice 312 by 1 pixels
# Shifting slice 313 by 1 pixels
# Shifting slice 314 by 1 pixels
# Shifting slice 315 by 1 pixels
# Shifting slice 316 by 1 pixels
# Shifting slice 317 by 1 pixels
# Shifting slice 318 by 1 pixels
# Shifting slice 319 by 1 pixels
# Shifting slice 320 by 1 pixels
# Shifting slice 321 by 1 pixels
# Shifting slice 322 by 1 pixels
# Shifting slice 323 by 1 pixels
# Shifting slice 324 by 1 pixels
# Shifting slice 325 by 1 pixels
# Shifting slice 326 by 1 pixels
# Shifting slice 327 by 1 pixels
# Shifting slice 328 by 1 pixels
# Shifting slice 329 by 1 pixels
# Shifting slice 330 by 1 pixels
# Shifting slice 331 by 1 pixels
# Shifting slice 332 by 1 pixels
# Shifting slice 333 by 1 pixels
# Shifting slice 334 by 1 pixels
# Shifting slice 335 by 1 pixels
# Shifting slice 336 by 1 pixels
# Shifting slice 337 by 1 pixels
# Shifting slice 338 by 1 pixels
# Shifting slice 339 by 1 pixels
# Shifting slice 340 by 1 pixels
# Shifting slice 341 by 1 pixels
# Shifting slice 342 by 1 pixels
# Shifting slice 343 by 1 pixels
# Shifting slice 344 by 1 pixels
# Shifting slice 345 by 1 pixels
# Shifting slice 346 by 1 pixels
# Shifting slice 347 by 1 pixels
# Shifting slice 348 by 1 pixels
# Shifting slice 349 by 1 pixels
# Shifting slice 350 by 1 pixels
# Shifting slice 351 by 1 pixels
# Shifting slice 352 by 1 pixels
# Shifting slice 353 by 1 pixels
# Shifting slice 354 by 1 pixels
# Shifting slice 355 by 1 pixels
# Shifting slice 356 by 1 pixels
# Shifting slice 357 by 1 pixels
# Shifting slice 358 by 1 pixels
# Shifting slice 359 by 1 pixels
# Shifting slice 360 by 1 pixels
# Shifting slice 361 by 1 pixels
# Shifting slice 362 by 1 pixels
# Shifting slice 363 by 1 pixels
# Shifting slice 364 by 1 pixels
# Shifting slice 365 by 1 pixels
# Shifting slice 366 by 1 pixels
# Shifting slice 367 by 1 pixels
# Shifting slice 368 by 1 pixels
# Shifting slice 369 by 1 pixels
# Shifting slice 370 by 1 pixels
# Shifting slice 371 by 1 pixels
# Shifting slice 372 by 1 pixels
# Shifting slice 373 by 1 pixels
# Shifting slice 374 by 1 pixels
# Shifting slice 375 by 1 pixels
# Shifting slice 376 by 1 pixels
# Shifting slice 377 by 1 pixels
# Shifting slice 378 by 1 pixels
# Shifting slice 379 by 1 pixels
# Shifting slice 380 by 1 pixels
# Shifting slice 381 by 1 pixels
# Shifting slice 382 by 1 pixels
# Shifting slice 383 by 1 pixels
# Shifting slice 384 by 1 pixels
# Shifting slice 385 by 1 pixels
# Shifting slice 386 by 1 pixels
# Shifting slice 387 by 1 pixels
# Shifting slice 388 by 1 pixels
# Shifting slice 389 by 1 pixels
# Shifting slice 390 by 1 pixels
# Shifting slice 391 by 1 pixels
# Shifting slice 392 by 1 pixels
# Shifting slice 393 by 1 pixels
# Shifting slice 394 by 1 pixels
# Shifting slice 395 by 1 pixels
# Shifting slice 396 by 1 pixels
# Shifting slice 397 by 1 pixels
# Shifting slice 398 by 1 pixels
# Shifting slice 399 by 1 pixels
# Shifting slice 400 by 1 pixels
# Shifting slice 401 by 1 pixels
# Shifting slice 402 by 1 pixels
# Shifting slice 403 by 1 pixels
# Shifting slice 404 by 1 pixels
# Shifting slice 405 by 1 pixels
# Shifting slice 406 by 1 pixels
# Shifting slice 407 by 1 pixels
# Shifting slice 408 by 1 pixels
# Shifting slice 409 by 1 pixels
# Shifting slice 410 by 1 pixels
# Shifting slice 411 by 1 pixels
# Shifting slice 412 by 1 pixels
# Shifting slice 413 by 1 pixels
# Shifting slice 414 by 1 pixels
# Shifting slice 415 by 1 pixels
# Shifting slice 416 by 1 pixels
# Shifting slice 417 by 1 pixels
# Shifting slice 418 by 1 pixels
# Shifting slice 419 by 1 pixels
# Shifting slice 420 by 1 pixels
# Shifting slice 421 by 1 pixels
# Shifting slice 422 by 1 pixels
# Shifting slice 423 by 1 pixels
# Shifting slice 424 by 1 pixels
# Shifting slice 425 by 1 pixels
# Shifting slice 426 by 1 pixels
# Shifting slice 427 by 1 pixels
# Shifting slice 428 by 1 pixels
# Shifting slice 429 by 1 pixels
# Shifting slice 430 by 1 pixels
# Shifting slice 431 by 1 pixels
# Shifting slice 432 by 1 pixels
# Shifting slice 433 by 1 pixels
# Shifting slice 434 by 1 pixels
# Shifting slice 435 by 1 pixels
# Shifting slice 436 by 1 pixels
# Shifting slice 437 by 1 pixels
# Shifting slice 438 by 1 pixels
# Shifting slice 439 by 1 pixels
# Shifting slice 440 by 1 pixels
# Shifting slice 441 by 1 pixels
# Shifting slice 442 by 1 pixels
# Shifting slice 443 by 1 pixels
# Shifting slice 444 by 1 pixels
# Shifting slice 445 by 1 pixels
# Shifting slice 446 by 1 pixels
# Shifting slice 447 by 1 pixels
# Shifting slice 448 by 1 pixels
# Shifting slice 449 by 1 pixels
# Shifting slice 450 by 1 pixels
# Shifting slice 451 by 1 pixels
# Shifting slice 452 by 1 pixels
# Shifting slice 453 by 1 pixels
# Shifting slice 454 by 1 pixels
# Shifting slice 455 by 1 pixels
# Shifting slice 456 by 1 pixels
# Shifting slice 457 by 1 pixels
# Shifting slice 458 by 1 pixels
# Shifting slice 459 by 1 pixels
# Shifting slice 460 by 1 pixels
# Shifting slice 461 by 1 pixels
# Shifting slice 462 by 1 pixels
# Shifting slice 463 by 1 pixels
# Shifting slice 464 by 1 pixels
# Shifting slice 465 by 1 pixels
# Shifting slice 466 by 1 pixels
# Shifting slice 467 by 1 pixels
# Shifting slice 468 by 1 pixels
# Shifting slice 469 by 1 pixels
# Shifting slice 470 by 1 pixels
# Shifting slice 471 by 1 pixels
# Shifting slice 472 by 1 pixels
# Shifting slice 473 by 1 pixels
# Shifting slice 474 by 1 pixels
# Shifting slice 475 by 1 pixels
# Shifting slice 476 by 1 pixels
# Shifting slice 477 by 1 pixels
# Shifting slice 478 by 1 pixels
# Shifting slice 479 by 1 pixels
# Shifting slice 480 by 1 pixels
# Shifting slice 481 by 1 pixels
# Shifting slice 482 by 1 pixels
# Shifting slice 483 by 1 pixels
# Shifting slice 484 by 1 pixels
# Shifting slice 485 by 1 pixels
# Shifting slice 486 by 1 pixels
# Shifting slice 487 by 1 pixels
# Shifting slice 488 by 1 pixels
# Shifting slice 489 by 1 pixels
# Shifting slice 490 by 1 pixels
# Shifting slice 491 by 1 pixels
# Shifting slice 492 by 1 pixels
# Shifting slice 493 by 1 pixels
# Shifting slice 494 by 1 pixels
# Shifting slice 495 by 1 pixels
# Shifting slice 496 by 1 pixels
# Shifting slice 497 by 1 pixels
# Shifting slice 498 by 1 pixels
# Shifting slice 499 by 1 pixels
# Shifting slice 500 by 1 pixels
# Shifting slice 501 by 1 pixels
# Shifting slice 502 by 1 pixels
# Shifting slice 503 by 1 pixels
# Shifting slice 504 by 1 pixels
# Shifting slice 505 by 1 pixels
# Shifting slice 506 by 1 pixels
# Shifting slice 507 by 1 pixels
# Shifting slice 508 by 1 pixels
# Shifting slice 509 by 1 pixels
# Shifting slice 510 by 1 pixels
# Shifting slice 511 by 1 pixels
# Shifting slice 512 by 1 pixels
# Shifting slice 513 by 1 pixels
# Shifting slice 514 by 1 pixels
# Shifting slice 515 by 1 pixels
# Shifting slice 516 by 1 pixels
# Shifting slice 517 by 1 pixels
# Shifting slice 518 by 1 pixels
# Shifting slice 519 by 1 pixels
# Shifting slice 520 by 1 pixels
# Shifting slice 521 by 1 pixels
# Shifting slice 522 by 1 pixels
# Shifting slice 523 by 1 pixels
# Shifting slice 524 by 1 pixels
# Shifting slice 525 by 1 pixels
# Shifting slice 526 by 1 pixels
# Shifting slice 527 by 1 pixels
# Shifting slice 528 by 1 pixels
# Shifting slice 529 by 1 pixels
# Shifting slice 530 by 1 pixels
# Shifting slice 531 by 1 pixels
# Shifting slice 532 by 1 pixels
# Shifting slice 533 by 1 pixels
# Shifting slice 534 by 1 pixels
# Shifting slice 535 by 1 pixels
# Shifting slice 536 by 1 pixels
# Shifting slice 537 by 1 pixels
# Shifting slice 538 by 1 pixels
# Shifting slice 539 by 1 pixels
# Shifting slice 540 by 1 pixels
# Shifting slice 541 by 1 pixels
# Shifting slice 542 by 1 pixels
# Shifting slice 543 by 1 pixels
# Shifting slice 544 by 1 pixels
# Shifting slice 545 by 1 pixels
# Shifting slice 546 by 1 pixels
# Shifting slice 547 by 1 pixels
# Shifting slice 548 by 1 pixels
# Shifting slice 549 by 1 pixels
# Shifting slice 550 by 1 pixels
# Shifting slice 551 by 1 pixels
# Shifting slice 552 by 1 pixels
# Shifting slice 553 by 1 pixels
# Shifting slice 554 by 1 pixels
# Shifting slice 555 by 1 pixels
# Shifting slice 556 by 1 pixels
# Shifting slice 557 by 1 pixels
# Shifting slice 558 by 1 pixels
# Shifting slice 559 by 1 pixels
# Shifting slice 560 by 1 pixels
# Shifting slice 561 by 1 pixels
# Shifting slice 562 by 1 pixels
# Shifting slice 563 by 1 pixels
# Shifting slice 564 by 1 pixels
# Shifting slice 565 by 1 pixels
# Shifting slice 566 by 1 pixels
# Shifting slice 567 by 1 pixels
# Shifting slice 568 by 1 pixels
# Shifting slice 569 by 1 pixels
# Shifting slice 570 by 1 pixels
# Shifting slice 571 by 1 pixels
# Shifting slice 572 by 1 pixels
# Shifting slice 573 by 1 pixels
# Shifting slice 574 by 1 pixels
# Shifting slice 575 by 1 pixels
# Shifting slice 576 by 1 pixels
# Shifting slice 577 by 1 pixels
# Shifting slice 578 by 1 pixels
# Shifting slice 579 by 1 pixels
# Shifting slice 580 by 1 pixels
# Shifting slice 581 by 1 pixels
# Shifting slice 582 by 1 pixels
# Shifting slice 583 by 1 pixels
# Shifting slice 584 by 1 pixels
# Shifting slice 585 by 1 pixels
# Shifting slice 586 by 1 pixels
# Shifting slice 587 by 1 pixels
# Shifting slice 588 by 1 pixels
# Shifting slice 589 by 1 pixels
# Shifting slice 590 by 1 pixels
# Shifting slice 591 by 1 pixels
# Shifting slice 592 by 1 pixels
# Shifting slice 593 by 1 pixels
# Shifting slice 594 by 1 pixels
# Shifting slice 595 by 1 pixels
# Shifting slice 596 by 1 pixels
# Shifting slice 597 by 1 pixels
# Shifting slice 598 by 1 pixels
# Shifting slice 599 by 1 pixels
# Shifting slice 600 by 1 pixels
# Shifting slice 601 by 1 pixels
# Shifting slice 602 by 1 pixels
# Shifting slice 603 by 1 pixels
# Shifting slice 604 by 1 pixels
# Shifting slice 605 by 1 pixels
# Shifting slice 606 by 1 pixels
# Shifting slice 607 by 1 pixels
# Shifting slice 608 by 1 pixels
# Shifting slice 609 by 1 pixels
# Shifting slice 610 by 1 pixels
# Shifting slice 611 by 1 pixels
# Shifting slice 612 by 1 pixels
# Shifting slice 613 by 1 pixels
# Shifting slice 614 by 1 pixels
# Shifting slice 615 by 1 pixels
# Shifting slice 616 by 1 pixels
# Shifting slice 617 by 1 pixels
# Shifting slice 618 by 1 pixels
# Shifting slice 619 by 1 pixels
# Shifting slice 620 by 1 pixels
# Shifting slice 621 by 1 pixels
# Shifting slice 622 by 1 pixels
# Shifting slice 623 by 1 pixels
# Shifting slice 624 by 1 pixels
# Shifting slice 625 by 1 pixels
# Shifting slice 626 by 1 pixels
# Shifting slice 627 by 1 pixels
# Shifting slice 628 by 1 pixels
# Shifting slice 629 by 1 pixels
# Shifting slice 630 by 1 pixels
# Shifting slice 631 by 1 pixels
# Shifting slice 632 by 1 pixels
# Shifting slice 633 by 1 pixels
# Shifting slice 634 by 1 pixels
# Shifting slice 635 by 1 pixels
# Shifting slice 636 by 1 pixels
# Shifting slice 637 by 1 pixels
# Shifting slice 638 by 1 pixels
# Shifting slice 639 by 1 pixels
# Shifting slice 640 by 1 pixels
# Shifting slice 641 by 1 pixels
# Shifting slice 642 by 1 pixels
# Shifting slice 643 by 1 pixels
# Shifting slice 644 by 1 pixels
# Shifting slice 645 by 1 pixels
# Shifting slice 646 by 1 pixels
# Shifting slice 647 by 1 pixels
# Shifting slice 648 by 1 pixels
# Shifting slice 649 by 1 pixels
# Shifting slice 650 by 1 pixels
# Shifting slice 651 by 1 pixels
# Shifting slice 652 by 1 pixels
# Shifting slice 653 by 1 pixels
# Shifting slice 654 by 1 pixels
# Shifting slice 655 by 1 pixels
# Shifting slice 656 by 1 pixels
# Shifting slice 657 by 1 pixels
# Shifting slice 658 by 1 pixels
# Shifting slice 659 by 1 pixels
# Shifting slice 660 by 1 pixels
# Shifting slice 661 by 1 pixels
# Shifting slice 662 by 1 pixels
# Shifting slice 663 by 1 pixels
# Shifting slice 664 by 1 pixels
# Shifting slice 665 by 1 pixels
# Shifting slice 666 by 1 pixels
# Shifting slice 667 by 1 pixels
# Shifting slice 668 by 1 pixels
# Shifting slice 669 by 1 pixels
# Shifting slice 670 by 1 pixels
# Shifting slice 671 by 1 pixels
# Shifting slice 672 by 1 pixels
# Shifting slice 673 by 1 pixels
# Shifting slice 674 by 1 pixels
# Shifting slice 675 by 1 pixels
# Shifting slice 676 by 1 pixels
# Shifting slice 677 by 1 pixels
# Shifting slice 678 by 1 pixels
# Shifting slice 679 by 1 pixels
# Shifting slice 680 by 1 pixels
# Shifting slice 681 by 1 pixels
# Shifting slice 682 by 1 pixels
# Shifting slice 683 by 1 pixels
# Shifting slice 684 by 1 pixels
# Shifting slice 685 by 1 pixels
# Shifting slice 686 by 1 pixels
# Shifting slice 687 by 1 pixels
# Shifting slice 688 by 1 pixels
# Shifting slice 689 by 1 pixels
# Shifting slice 690 by 1 pixels
# Shifting slice 691 by 1 pixels
# Shifting slice 692 by 1 pixels
# Shifting slice 693 by 1 pixels
# Shifting slice 694 by 1 pixels
# Shifting slice 695 by 1 pixels
# Shifting slice 696 by 1 pixels
# Shifting slice 697 by 1 pixels
# Shifting slice 698 by 1 pixels
# Shifting slice 699 by 1 pixels
# Shifting slice 700 by 1 pixels
# Shifting slice 701 by 1 pixels
# Shifting slice 702 by 1 pixels
# Shifting slice 703 by 1 pixels
# Shifting slice 704 by 1 pixels
# Shifting slice 705 by 1 pixels
# Shifting slice 706 by 1 pixels
# Shifting slice 707 by 1 pixels
# Shifting slice 708 by 1 pixels
# Shifting slice 709 by 1 pixels
# Shifting slice 710 by 1 pixels
# Shifting slice 711 by 1 pixels
# Shifting slice 712 by 1 pixels
# Shifting slice 713 by 1 pixels
# Shifting slice 714 by 1 pixels
# Shifting slice 715 by 1 pixels
# Shifting slice 716 by 1 pixels
# Shifting slice 717 by 1 pixels
# Shifting slice 718 by 1 pixels
# Shifting slice 719 by 1 pixels
# Shifting slice 720 by 1 pixels
# Shifting slice 721 by 1 pixels
# Shifting slice 722 by 1 pixels
# Shifting slice 723 by 1 pixels
# Shifting slice 724 by 1 pixels
# Shifting slice 725 by 1 pixels
# Shifting slice 726 by 1 pixels
# Shifting slice 727 by 1 pixels
# Shifting slice 728 by 1 pixels
# Shifting slice 729 by 1 pixels
# Shifting slice 730 by 1 pixels
# Shifting slice 731 by 1 pixels
# Shifting slice 732 by 1 pixels
# Shifting slice 733 by 1 pixels
# Shifting slice 734 by 1 pixels
# Shifting slice 735 by 1 pixels
# Shifting slice 736 by 1 pixels
# Shifting slice 737 by 1 pixels
# Shifting slice 738 by 1 pixels
# Shifting slice 739 by 1 pixels
# Shifting slice 740 by 1 pixels
# Shifting slice 741 by 1 pixels
# Shifting slice 742 by 1 pixels
# Shifting slice 743 by 1 pixels
# Shifting slice 744 by 1 pixels
# Shifting slice 745 by 1 pixels
# Shifting slice 746 by 1 pixels
# Shifting slice 747 by 1 pixels
# Shifting slice 748 by 1 pixels
# Shifting slice 749 by 1 pixels
# Shifting slice 750 by 1 pixels
# Shifting slice 751 by 1 pixels
# Shifting slice 752 by 1 pixels
# Shifting slice 753 by 1 pixels
# Shifting slice 754 by 1 pixels
# Shifting slice 755 by 1 pixels
# Shifting slice 756 by 1 pixels
# Shifting slice 757 by 1 pixels
# Shifting slice 758 by 1 pixels
# Shifting slice 759 by 1 pixels
# Shifting slice 760 by 1 pixels
# Shifting slice 761 by 1 pixels
# Shifting slice 762 by 1 pixels
# Shifting slice 763 by 1 pixels
# Shifting slice 764 by 1 pixels
# Shifting slice 765 by 1 pixels
# Shifting slice 766 by 1 pixels
# Shifting slice 767 by 1 pixels
# Shifting slice 768 by 1 pixels
# Shifting slice 769 by 1 pixels
# Shifting slice 770 by 1 pixels
# Shifting slice 771 by 1 pixels
# Shifting slice 772 by 1 pixels
# Shifting slice 773 by 1 pixels
# Shifting slice 774 by 1 pixels
# Shifting slice 775 by 1 pixels
# Shifting slice 776 by 1 pixels
# Shifting slice 777 by 1 pixels
# Shifting slice 778 by 1 pixels
# Shifting slice 779 by 1 pixels
# Shifting slice 780 by 1 pixels
# Shifting slice 781 by 1 pixels
# Shifting slice 782 by 1 pixels
# Shifting slice 783 by 1 pixels
# Shifting slice 784 by 1 pixels
# Shifting slice 785 by 1 pixels
# Shifting slice 786 by 1 pixels
# Shifting slice 787 by 1 pixels
# Shifting slice 788 by 1 pixels
# Shifting slice 789 by 1 pixels
# Shifting slice 790 by 1 pixels
# Shifting slice 791 by 1 pixels
# Shifting slice 792 by 1 pixels
# Shifting slice 793 by 1 pixels
# Shifting slice 794 by 1 pixels
# Shifting slice 795 by 1 pixels
# Shifting slice 796 by 1 pixels
# Shifting slice 797 by 1 pixels
# Shifting slice 798 by 1 pixels
# Shifting slice 799 by 1 pixels
# Shifting slice 800 by 1 pixels
# Shifting slice 801 by 1 pixels
# Shifting slice 802 by 1 pixels
# Shifting slice 803 by 1 pixels
# Shifting slice 804 by 1 pixels
# Shifting slice 805 by 1 pixels
# Shifting slice 806 by 1 pixels
# Shifting slice 807 by 1 pixels
# Shifting slice 808 by 1 pixels
# Shifting slice 809 by 1 pixels
# Shifting slice 810 by 1 pixels
# Shifting slice 811 by 1 pixels
# Shifting slice 812 by 1 pixels
# Shifting slice 813 by 1 pixels
# Shifting slice 814 by 1 pixels
# Shifting slice 815 by 1 pixels
# Shifting slice 816 by 1 pixels
# Shifting slice 817 by 1 pixels
# Shifting slice 818 by 1 pixels
# Shifting slice 819 by 1 pixels
# Shifting slice 820 by 1 pixels
# Shifting slice 821 by 1 pixels
# Shifting slice 822 by 1 pixels
# Shifting slice 823 by 1 pixels
# Shifting slice 824 by 1 pixels
# Shifting slice 825 by 1 pixels
# Shifting slice 826 by 1 pixels
# Shifting slice 827 by 1 pixels
# Shifting slice 828 by 1 pixels
# Shifting slice 829 by 1 pixels
# Shifting slice 830 by 1 pixels
# Shifting slice 831 by 1 pixels
# Shifting slice 832 by 1 pixels
# Shifting slice 833 by 1 pixels
# Shifting slice 834 by 1 pixels
# Shifting slice 835 by 1 pixels
# Shifting slice 836 by 1 pixels
# Shifting slice 837 by 1 pixels
# Shifting slice 838 by 1 pixels
# Shifting slice 839 by 1 pixels
# Shifting slice 840 by 1 pixels
# Shifting slice 841 by 1 pixels
# Shifting slice 842 by 1 pixels
# Shifting slice 843 by 1 pixels
# Shifting slice 844 by 1 pixels
# Shifting slice 845 by 1 pixels
# Shifting slice 846 by 1 pixels
# Shifting slice 847 by 1 pixels
# Shifting slice 848 by 1 pixels
# Shifting slice 849 by 1 pixels
# Shifting slice 850 by 1 pixels
# Shifting slice 851 by 1 pixels
# Shifting slice 852 by 1 pixels
# Shifting slice 853 by 1 pixels
# Shifting slice 854 by 1 pixels
# Shifting slice 855 by 1 pixels
# Shifting slice 856 by 1 pixels
# Shifting slice 857 by 1 pixels
# Shifting slice 858 by 1 pixels
# Shifting slice 859 by 1 pixels
# Shifting slice 860 by 1 pixels
# Shifting slice 861 by 1 pixels
# Shifting slice 862 by 1 pixels
# Shifting slice 863 by 1 pixels
# Shifting slice 864 by 1 pixels
# Shifting slice 865 by 1 pixels
# Shifting slice 866 by 1 pixels
# Shifting slice 867 by 1 pixels
# Shifting slice 868 by 1 pixels
# Shifting slice 869 by 1 pixels
# Shifting slice 870 by 1 pixels
# Shifting slice 871 by 1 pixels
# Shifting slice 872 by 1 pixels
# Shifting slice 873 by 1 pixels
# Shifting slice 874 by 1 pixels
# Shifting slice 875 by 1 pixels
# Shifting slice 876 by 1 pixels
# Shifting slice 877 by 1 pixels
# Shifting slice 878 by 1 pixels
# Shifting slice 879 by 1 pixels
# Shifting slice 880 by 1 pixels
# Shifting slice 881 by 1 pixels
# Shifting slice 882 by 1 pixels
# Shifting slice 883 by 1 pixels
# Shifting slice 884 by 1 pixels
# Shifting slice 885 by 1 pixels
# Shifting slice 886 by 1 pixels
# Shifting slice 887 by 1 pixels
# Shifting slice 888 by 1 pixels
# Shifting slice 889 by 1 pixels
# Shifting slice 890 by 1 pixels
# Shifting slice 891 by 1 pixels
# Shifting slice 892 by 1 pixels
# Shifting slice 893 by 1 pixels
# Shifting slice 894 by 1 pixels
# Shifting slice 895 by 1 pixels
# Shifting slice 896 by 1 pixels
# Shifting slice 897 by 1 pixels
# Shifting slice 898 by 1 pixels
# Shifting slice 899 by 1 pixels
# Shifting slice 900 by 1 pixels
# Shifting slice 901 by 1 pixels
# Shifting slice 902 by 1 pixels
# Shifting slice 903 by 1 pixels
# Shifting slice 904 by 1 pixels
# Shifting slice 905 by 1 pixels
# Shifting slice 906 by 1 pixels
# Shifting slice 907 by 1 pixels
# Shifting slice 908 by 1 pixels
# Shifting slice 909 by 1 pixels
# Shifting slice 910 by 1 pixels
# Shifting slice 911 by 1 pixels
# Shifting slice 912 by 1 pixels
# Shifting slice 913 by 1 pixels
# Shifting slice 914 by 1 pixels
# Shifting slice 915 by 1 pixels
# Shifting slice 916 by 1 pixels
# Shifting slice 917 by 1 pixels
# Shifting slice 918 by 1 pixels
# Shifting slice 919 by 1 pixels
# Shifting slice 920 by 1 pixels
# Shifting slice 921 by 1 pixels
# Shifting slice 922 by 1 pixels
# Shifting slice 923 by 1 pixels
# Shifting slice 924 by 1 pixels
# Shifting slice 925 by 1 pixels
# Shifting slice 926 by 1 pixels
# Shifting slice 927 by 1 pixels
# Shifting slice 928 by 1 pixels
# Shifting slice 929 by 1 pixels
# Shifting slice 930 by 1 pixels
# Shifting slice 931 by 1 pixels
# Shifting slice 932 by 1 pixels
# Shifting slice 933 by 1 pixels
# Shifting slice 934 by 1 pixels
# Shifting slice 935 by 1 pixels
# Shifting slice 936 by 1 pixels
# Shifting slice 937 by 1 pixels
# Shifting slice 938 by 1 pixels
# Shifting slice 939 by 1 pixels
# Shifting slice 940 by 1 pixels
# Shifting slice 941 by 1 pixels
# Shifting slice 942 by 1 pixels
# Shifting slice 943 by 1 pixels
# Shifting slice 944 by 1 pixels
# Shifting slice 945 by 1 pixels
# Shifting slice 946 by 1 pixels
# Shifting slice 947 by 1 pixels
# Shifting slice 948 by 1 pixels
# Shifting slice 949 by 1 pixels
# Shifting slice 950 by 1 pixels
# Shifting slice 951 by 1 pixels
# Shifting slice 952 by 1 pixels
# Shifting slice 953 by 1 pixels
# Shifting slice 954 by 1 pixels
# Shifting slice 955 by 1 pixels
# Shifting slice 956 by 1 pixels
# Shifting slice 957 by 1 pixels
# Shifting slice 958 by 1 pixels
# Shifting slice 959 by 1 pixels
# Shifting slice 960 by 1 pixels
# Shifting slice 961 by 1 pixels
# Shifting slice 962 by 1 pixels
# Shifting slice 963 by 1 pixels
# Shifting slice 964 by 1 pixels
# Shifting slice 965 by 1 pixels
# Shifting slice 966 by 1 pixels
# Shifting slice 967 by 1 pixels
# Shifting slice 968 by 1 pixels
# Shifting slice 969 by 1 pixels
# Shifting slice 970 by 1 pixels
# Shifting slice 971 by 1 pixels
# Shifting slice 972 by 1 pixels
# Shifting slice 973 by 1 pixels
# Shifting slice 974 by 1 pixels
# Shifting slice 975 by 1 pixels
# Shifting slice 976 by 1 pixels
# Shifting slice 977 by 1 pixels
# Shifting slice 978 by 1 pixels
# Shifting slice 979 by 1 pixels
# Shifting slice 980 by 1 pixels
# Shifting slice 981 by 1 pixels
# Shifting slice 982 by 1 pixels
# Shifting slice 983 by 1 pixels
# Shifting slice 984 by 1 pixels
# Shifting slice 985 by 1 pixels
# Shifting slice 986 by 1 pixels
# Shifting slice 987 by 1 pixels
# Shifting slice 988 by 1 pixels
# Shifting slice 989 by 1 pixels
# Shifting slice 990 by 1 pixels
# Shifting slice 991 by 1 pixels
# Shifting slice 992 by 1 pixels
# Shifting slice 993 by 1 pixels
# Shifting slice 994 by 1 pixels
# Shifting slice 995 by 1 pixels
# Shifting slice 996 by 1 pixels
# Shifting slice 997 by 1 pixels
# Shifting slice 998 by 1 pixels
# Shifting slice 999 by 1 pixels
# Shifting slice 1000 by 1 pixels
# Shifting slice 1001 by 1 pixels
# Shifting slice 1002 by 1 pixels
# Shifting slice 1003 by 1 pixels
# Shifting slice 1004 by 1 pixels
# Shifting slice 1005 by 1 pixels
# Shifting slice 1006 by 1 pixels
# Shifting slice 1007 by 1 pixels
# Shifting slice 1008 by 1 pixels
# Shifting slice 1009 by 1 pixels
# Shifting slice 1010 by 1 pixels
# Shifting slice 1011 by 1 pixels
# Shifting slice 1012 by 1 pixels
# Shifting slice 1013 by 1 pixels
# Shifting slice 1014 by 1 pixels
# Shifting slice 1015 by 1 pixels
# Shifting slice 1016 by 1 pixels
# Shifting slice 1017 by 1 pixels
# Shifting slice 1018 by 1 pixels
# Shifting slice 1019 by 1 pixels
# Shifting slice 1020 by 1 pixels
# Shifting slice 1021 by 1 pixels
# Shifting slice 1022 by 1 pixels
# Shifting slice 1023 by 1 pixels
# Shifting slice 1024 by 1 pixels
# Shifting slice 1025 by 1 pixels
# Shifting slice 1026 by 1 pixels
# Shifting slice 1027 by 1 pixels
# Shifting slice 1028 by 1 pixels
# Shifting slice 1029 by 1 pixels
# Shifting slice 1030 by 1 pixels
# Shifting slice 1031 by 1 pixels
# Shifting slice 1032 by 1 pixels
# Shifting slice 1033 by 1 pixels
# Shifting slice 1034 by 1 pixels
# Shifting slice 1035 by 1 pixels
# Shifting slice 1036 by 1 pixels
# Shifting slice 1037 by 1 pixels
# Shifting slice 1038 by 1 pixels
# Shifting slice 1039 by 1 pixels
# Shifting slice 1040 by 1 pixels
# Shifting slice 1041 by 1 pixels
# Shifting slice 1042 by 1 pixels
# Shifting slice 1043 by 1 pixels
# Shifting slice 1044 by 1 pixels
# Shifting slice 1045 by 1 pixels
# Shifting slice 1046 by 1 pixels
# Shifting slice 1047 by 1 pixels
# Shifting slice 1048 by 1 pixels
# Shifting slice 1049 by 1 pixels
# Shifting slice 1050 by 1 pixels
# Shifting slice 1051 by 1 pixels
# Shifting slice 1052 by 1 pixels
# Shifting slice 1053 by 1 pixels
# Shifting slice 1054 by 1 pixels
# Shifting slice 1055 by 1 pixels
# Shifting slice 1056 by 1 pixels
# Shifting slice 1057 by 1 pixels
# Shifting slice 1058 by 1 pixels
# Shifting slice 1059 by 1 pixels
# Shifting slice 1060 by 1 pixels
# Shifting slice 1061 by 1 pixels
# Shifting slice 1062 by 1 pixels
# Shifting slice 1063 by 1 pixels
# Shifting slice 1064 by 1 pixels
# Shifting slice 1065 by 1 pixels
# Shifting slice 1066 by 1 pixels
# Shifting slice 1067 by 1 pixels
# Shifting slice 1068 by 1 pixels
# Shifting slice 1069 by 1 pixels
# Shifting slice 1070 by 1 pixels
# Shifting slice 1071 by 1 pixels
# Shifting slice 1072 by 1 pixels
# Shifting slice 1073 by 1 pixels
# Shifting slice 1074 by 1 pixels
# Shifting slice 1075 by 1 pixels
# Shifting slice 1076 by 1 pixels
# Shifting slice 1077 by 1 pixels
# Shifting slice 1078 by 1 pixels
# Shifting slice 1079 by 1 pixels
# Shifting slice 1080 by 1 pixels
# Shifting slice 1081 by 1 pixels
# Shifting slice 1082 by 1 pixels
# Shifting slice 1083 by 1 pixels
# Shifting slice 1084 by 1 pixels
# Shifting slice 1085 by 1 pixels
# Shifting slice 1086 by 1 pixels
# Shifting slice 1087 by 1 pixels
# Shifting slice 1088 by 1 pixels
# Shifting slice 1089 by 1 pixels
# Shifting slice 1090 by 1 pixels
# Shifting slice 1091 by 1 pixels
# Shifting slice 1092 by 1 pixels
# Shifting slice 1093 by 1 pixels
# Shifting slice 1094 by 1 pixels
# Shifting slice 1095 by 1 pixels
# Shifting slice 1096 by 1 pixels
# Shifting slice 1097 by 1 pixels
# Shifting slice 1098 by 1 pixels
# Shifting slice 1099 by 1 pixels
# Shifting slice 1100 by 1 pixels
# Shifting slice 1101 by 1 pixels
# Shifting slice 1102 by 1 pixels
# Shifting slice 1103 by 1 pixels
# Shifting slice 1104 by 1 pixels
# Shifting slice 1105 by 1 pixels
# Shifting slice 1106 by 1 pixels
# Shifting slice 1107 by 1 pixels
# Shifting slice 1108 by 1 pixels
# Shifting slice 1109 by 1 pixels
# Shifting slice 1110 by 1 pixels
# Shifting slice 1111 by 1 pixels
# Shifting slice 1112 by 1 pixels
# Shifting slice 1113 by 1 pixels
# Shifting slice 1114 by 1 pixels
# Shifting slice 1115 by 1 pixels
# Shifting slice 1116 by 1 pixels
# Shifting slice 1117 by 1 pixels
# Shifting slice 1118 by 1 pixels
# Shifting slice 1119 by 1 pixels
# Shifting slice 1120 by 1 pixels
# Shifting slice 1121 by 1 pixels
# Shifting slice 1122 by 1 pixels
# Shifting slice 1123 by 1 pixels
# Shifting slice 1124 by 1 pixels
# Shifting slice 1125 by 1 pixels
# Shifting slice 1126 by 1 pixels
# Shifting slice 1127 by 1 pixels
# Shifting slice 1128 by 1 pixels
# Shifting slice 1129 by 1 pixels
# Shifting slice 1130 by 1 pixels
# Shifting slice 1131 by 1 pixels
# Shifting slice 1132 by 1 pixels
# Shifting slice 1133 by 1 pixels
# Shifting slice 1134 by 1 pixels
# Shifting slice 1135 by 1 pixels
# Shifting slice 1136 by 1 pixels
# Shifting slice 1137 by 1 pixels
# Shifting slice 1138 by 1 pixels
# Shifting slice 1139 by 1 pixels
# Shifting slice 1140 by 1 pixels
# Shifting slice 1141 by 1 pixels
# Shifting slice 1142 by 1 pixels
# Shifting slice 1143 by 1 pixels
# Shifting slice 1144 by 1 pixels
# Shifting slice 1145 by 1 pixels
# Shifting slice 1146 by 1 pixels
# Shifting slice 1147 by 1 pixels
# Shifting slice 1148 by 1 pixels
# Shifting slice 1149 by 1 pixels
# Shifting slice 1150 by 1 pixels
# Shifting slice 1151 by 1 pixels
# Shifting slice 1152 by 1 pixels
# Shifting slice 1153 by 1 pixels
# Shifting slice 1154 by 1 pixels
# Shifting slice 1155 by 1 pixels
# Shifting slice 1156 by 1 pixels
# Shifting slice 1157 by 1 pixels
# Shifting slice 1158 by 1 pixels
# Shifting slice 1159 by 1 pixels
# Shifting slice 1160 by 1 pixels
# Shifting slice 1161 by 1 pixels
# Shifting slice 1162 by 1 pixels
# Shifting slice 1163 by 1 pixels
# Shifting slice 1164 by 1 pixels
# Shifting slice 1165 by 1 pixels
# Shifting slice 1166 by 1 pixels
# Shifting slice 1167 by 1 pixels
# Shifting slice 1168 by 1 pixels
# Shifting slice 1169 by 1 pixels
# Shifting slice 1170 by 1 pixels
# Shifting slice 1171 by 1 pixels
# Shifting slice 1172 by 1 pixels
# Shifting slice 1173 by 1 pixels
# Shifting slice 1174 by 1 pixels
# Shifting slice 1175 by 1 pixels
# Shifting slice 1176 by 1 pixels
# Shifting slice 1177 by 1 pixels
# Shifting slice 1178 by 1 pixels
# Shifting slice 1179 by 1 pixels
# Shifting slice 1180 by 1 pixels
# Shifting slice 1181 by 1 pixels
# Shifting slice 1182 by 1 pixels
# Shifting slice 1183 by 1 pixels
# Shifting slice 1184 by 1 pixels
# Shifting slice 1185 by 1 pixels
# Shifting slice 1186 by 1 pixels
# Shifting slice 1187 by 1 pixels
# Shifting slice 1188 by 1 pixels
# Shifting slice 1189 by 1 pixels
# Shifting slice 1190 by 1 pixels
# Shifting slice 1191 by 1 pixels
# Shifting slice 1192 by 1 pixels
# Shifting slice 1193 by 1 pixels
# Shifting slice 1194 by 1 pixels
# Shifting slice 1195 by 1 pixels
# Shifting slice 1196 by 1 pixels
# Shifting slice 1197 by 1 pixels
# Shifting slice 1198 by 1 pixels
# Shifting slice 1199 by 1 pixels
# Shifting slice 1200 by 1 pixels
# Shifting slice 1201 by 1 pixels
# Shifting slice 1202 by 1 pixels
# Shifting slice 1203 by 1 pixels
# Shifting slice 1204 by 1 pixels
# Shifting slice 1205 by 1 pixels
# Shifting slice 1206 by 1 pixels
# Shifting slice 1207 by 1 pixels
# Shifting slice 1208 by 1 pixels
# Shifting slice 1209 by 1 pixels
# Shifting slice 1210 by 1 pixels
# Shifting slice 1211 by 1 pixels
# Shifting slice 1212 by 1 pixels
# Shifting slice 1213 by 1 pixels
# Shifting slice 1214 by 1 pixels
# Shifting slice 1215 by 1 pixels
# Shifting slice 1216 by 1 pixels
# Shifting slice 1217 by 1 pixels
# Shifting slice 1218 by 1 pixels
# Shifting slice 1219 by 1 pixels
# Shifting slice 1220 by 1 pixels
# Shifting slice 1221 by 1 pixels
# Shifting slice 1222 by 1 pixels
# Shifting slice 1223 by 1 pixels
# Shifting slice 1224 by 1 pixels
# Shifting slice 1225 by 1 pixels
# Shifting slice 1226 by 1 pixels
# Shifting slice 1227 by 1 pixels
# Shifting slice 1228 by 1 pixels
# Shifting slice 1229 by 1 pixels
# Shifting slice 1230 by 1 pixels
# Shifting slice 1231 by 1 pixels
# Shifting slice 1232 by 1 pixels
# Shifting slice 1233 by 1 pixels
# Shifting slice 1234 by 1 pixels
# Shifting slice 1235 by 1 pixels
# Shifting slice 1236 by 1 pixels
# Shifting slice 1237 by 1 pixels
# Shifting slice 1238 by 1 pixels
# Shifting slice 1239 by 1 pixels
# Shifting slice 1240 by 1 pixels
# Shifting slice 1241 by 1 pixels
# Shifting slice 1242 by 1 pixels
# Shifting slice 1243 by 1 pixels
# Shifting slice 1244 by 1 pixels
# Shifting slice 1245 by 1 pixels
# Shifting slice 1246 by 1 pixels
# Shifting slice 1247 by 1 pixels
# Shifting slice 1248 by 1 pixels
# Shifting slice 1249 by 1 pixels
# Shifting slice 1250 by 1 pixels
# Shifting slice 1251 by 1 pixels
# Shifting slice 1252 by 1 pixels
# Shifting slice 1253 by 1 pixels
# Shifting slice 1254 by 1 pixels
# Shifting slice 1255 by 1 pixels
# Shifting slice 1256 by 1 pixels
# Shifting slice 1257 by 1 pixels
# Shifting slice 1258 by 1 pixels
# Shifting slice 1259 by 1 pixels
# Shifting slice 1260 by 1 pixels
# Shifting slice 1261 by 1 pixels
# Shifting slice 1262 by 1 pixels
# Shifting slice 1263 by 1 pixels
# Shifting slice 1264 by 1 pixels
# Shifting slice 1265 by 1 pixels
# Shifting slice 1266 by 1 pixels
# Shifting slice 1267 by 1 pixels
# Shifting slice 1268 by 1 pixels
# Shifting slice 1269 by 1 pixels
# Shifting slice 1270 by 1 pixels
# Shifting slice 1271 by 1 pixels
# Shifting slice 1272 by 1 pixels
# Shifting slice 1273 by 1 pixels
# Shifting slice 1274 by 1 pixels
# Shifting slice 1275 by 1 pixels
# Shifting slice 1276 by 1 pixels
# Shifting slice 1277 by 1 pixels
# Shifting slice 1278 by 1 pixels
# Shifting slice 1279 by 1 pixels
# Shifting slice 1280 by 1 pixels
# Shifting slice 1281 by 1 pixels
# Shifting slice 1282 by 1 pixels
# Shifting slice 1283 by 1 pixels
# Shifting slice 1284 by 1 pixels
# Shifting slice 1285 by 1 pixels
# Shifting slice 1286 by 1 pixels
# Shifting slice 1287 by 1 pixels
# Shifting slice 1288 by 1 pixels
# Shifting slice 1289 by 1 pixels
# Shifting slice 1290 by 1 pixels
# Shifting slice 1291 by 1 pixels
# Shifting slice 1292 by 1 pixels
# Shifting slice 1293 by 1 pixels
# Shifting slice 1294 by 1 pixels
# Shifting slice 1295 by 1 pixels
# Shifting slice 1296 by 1 pixels
# Shifting slice 1297 by 1 pixels
# Shifting slice 1298 by 1 pixels
# Shifting slice 1299 by 1 pixels
# Shifting slice 1300 by 1 pixels
# Shifting slice 1301 by 1 pixels
# Shifting slice 1302 by 1 pixels
# Shifting slice 1303 by 1 pixels
# Shifting slice 1304 by 1 pixels
# Shifting slice 1305 by 1 pixels
# Shifting slice 1306 by 1 pixels
# Shifting slice 1307 by 1 pixels
# Shifting slice 1308 by 1 pixels
# Shifting slice 1309 by 1 pixels
# Shifting slice 1310 by 1 pixels
# Shifting slice 1311 by 1 pixels
# Shifting slice 1312 by 1 pixels
# Shifting slice 1313 by 1 pixels
# Shifting slice 1314 by 1 pixels
# Shifting slice 1315 by 1 pixels
# Shifting slice 1316 by 1 pixels
# Shifting slice 1317 by 1 pixels
# Shifting slice 1318 by 1 pixels
# Shifting slice 1319 by 1 pixels
# Shifting slice 1320 by 1 pixels
# Shifting slice 1321 by 1 pixels
# Shifting slice 1322 by 1 pixels
# Shifting slice 1323 by 1 pixels
# Shifting slice 1324 by 1 pixels
# Shifting slice 1325 by 1 pixels
# Shifting slice 1326 by 1 pixels
# Shifting slice 1327 by 1 pixels
# Shifting slice 1328 by 1 pixels
# Shifting slice 1329 by 1 pixels
# Shifting slice 1330 by 1 pixels
# Shifting slice 1331 by 1 pixels
# Shifting slice 1332 by 1 pixels
# Shifting slice 1333 by 1 pixels
# Shifting slice 1334 by 1 pixels
# Shifting slice 1335 by 1 pixels
# Shifting slice 1336 by 1 pixels
# Shifting slice 1337 by 1 pixels
# Shifting slice 1338 by 1 pixels
# Shifting slice 1339 by 1 pixels
# Shifting slice 1340 by 1 pixels
# Shifting slice 1341 by 1 pixels
# Shifting slice 1342 by 1 pixels
# Shifting slice 1343 by 1 pixels
# Shifting slice 1344 by 1 pixels
# Shifting slice 1345 by 1 pixels
# Shifting slice 1346 by 1 pixels
# Shifting slice 1347 by 1 pixels
# Shifting slice 1348 by 1 pixels
# Shifting slice 1349 by 1 pixels
# Shifting slice 1350 by 1 pixels
# Shifting slice 1351 by 1 pixels
# Shifting slice 1352 by 1 pixels
# Shifting slice 1353 by 1 pixels
# Shifting slice 1354 by 1 pixels
# Shifting slice 1355 by 1 pixels
# Shifting slice 1356 by 1 pixels
# Shifting slice 1357 by 1 pixels
# Shifting slice 1358 by 1 pixels
# Shifting slice 1359 by 1 pixels
# Shifting slice 1360 by 1 pixels
# Shifting slice 1361 by 1 pixels
# Shifting slice 1362 by 1 pixels
# Shifting slice 1363 by 1 pixels
# Shifting slice 1364 by 1 pixels
# Shifting slice 1365 by 1 pixels
# Shifting slice 1366 by 1 pixels
# Shifting slice 1367 by 1 pixels
# Shifting slice 1368 by 1 pixels
# Shifting slice 1369 by 1 pixels
# Shifting slice 1370 by 1 pixels
# Shifting slice 1371 by 1 pixels
# Shifting slice 1372 by 1 pixels
# Shifting slice 1373 by 1 pixels
# Shifting slice 1374 by 1 pixels
# Shifting slice 1375 by 1 pixels
# Shifting slice 1376 by 1 pixels
# Shifting slice 1377 by 1 pixels
# Shifting slice 1378 by 1 pixels
# Shifting slice 1379 by 1 pixels
# Shifting slice 1380 by 1 pixels
# Shifting slice 1381 by 1 pixels
# Shifting slice 1382 by 1 pixels
# Shifting slice 1383 by 1 pixels
# Shifting slice 1384 by 1 pixels
# Shifting slice 1385 by 1 pixels
# Shifting slice 1386 by 1 pixels
# Shifting slice 1387 by 1 pixels
# Shifting slice 1388 by 1 pixels
# Shifting slice 1389 by 1 pixels
# Shifting slice 1390 by 1 pixels
# Shifting slice 1391 by 1 pixels
# Shifting slice 1392 by 1 pixels
# Shifting slice 1393 by 1 pixels
# Shifting slice 1394 by 1 pixels
# Shifting slice 1395 by 1 pixels
# Shifting slice 1396 by 1 pixels
# Shifting slice 1397 by 1 pixels
# Shifting slice 1398 by 1 pixels
# Shifting slice 1399 by 1 pixels
# Shifting slice 1400 by 1 pixels
# Shifting slice 1401 by 1 pixels
# Shifting slice 1402 by 1 pixels
# Shifting slice 1403 by 1 pixels
# Shifting slice 1404 by 1 pixels
# Shifting slice 1405 by 1 pixels
# Shifting slice 1406 by 1 pixels
# Shifting slice 1407 by 1 pixels
# Shifting slice 1408 by 1 pixels
# Shifting slice 1409 by 1 pixels
# Shifting slice 1410 by 1 pixels
# Shifting slice 1411 by 1 pixels
# Shifting slice 1412 by 1 pixels
# Shifting slice 1413 by 1 pixels
# Shifting slice 1414 by 1 pixels
# Shifting slice 1415 by 1 pixels
# Shifting slice 1416 by 1 pixels
# Shifting slice 1417 by 1 pixels
# Shifting slice 1418 by 1 pixels
# Shifting slice 1419 by 1 pixels
# Shifting slice 1420 by 1 pixels
# Shifting slice 1421 by 1 pixels
# Shifting slice 1422 by 1 pixels
# Shifting slice 1423 by 1 pixels
# Shifting slice 1424 by 1 pixels
# Shifting slice 1425 by 1 pixels
# Shifting slice 1426 by 1 pixels
# Shifting slice 1427 by 1 pixels
# Shifting slice 1428 by 1 pixels
# Shifting slice 1429 by 1 pixels
# Shifting slice 1430 by 1 pixels
# Shifting slice 1431 by 1 pixels
# Shifting slice 1432 by 1 pixels
# Shifting slice 1433 by 1 pixels
# Shifting slice 1434 by 1 pixels
# Shifting slice 1435 by 1 pixels
# Shifting slice 1436 by 1 pixels
# Shifting slice 1437 by 1 pixels
# Shifting slice 1438 by 1 pixels
# Shifting slice 1439 by 1 pixels
# Shifting slice 1440 by 1 pixels
# Shifting slice 1441 by 1 pixels
# Shifting slice 1442 by 1 pixels
# Shifting slice 1443 by 1 pixels
# Shifting slice 1444 by 1 pixels
# Shifting slice 1445 by 1 pixels
# Shifting slice 1446 by 1 pixels
# Shifting slice 1447 by 1 pixels
# Shifting slice 1448 by 1 pixels
# Shifting slice 1449 by 1 pixels
# Shifting slice 1450 by 1 pixels
# Shifting slice 1451 by 1 pixels
# Shifting slice 1452 by 1 pixels
# Shifting slice 1453 by 1 pixels
# Shifting slice 1454 by 1 pixels
# Shifting slice 1455 by 1 pixels
# Shifting slice 1456 by 1 pixels
# Shifting slice 1457 by 1 pixels
# Shifting slice 1458 by 1 pixels
# Shifting slice 1459 by 1 pixels
# Shifting slice 1460 by 1 pixels
# Shifting slice 1461 by 1 pixels
# Shifting slice 1462 by 1 pixels
# Shifting slice 1463 by 1 pixels
# Shifting slice 1464 by 1 pixels
# Shifting slice 1465 by 1 pixels
# Shifting slice 1466 by 1 pixels
# Shifting slice 1467 by 1 pixels
# Shifting slice 1468 by 1 pixels
# Shifting slice 1469 by 1 pixels
# Shifting slice 1470 by 1 pixels
# Shifting slice 1471 by 1 pixels
# Shifting slice 1472 by 1 pixels
# Shifting slice 1473 by 1 pixels
# Shifting slice 1474 by 1 pixels
# Shifting slice 1475 by 1 pixels
# Shifting slice 1476 by 1 pixels
# Shifting slice 1477 by 1 pixels
# Shifting slice 1478 by 1 pixels
# Shifting slice 1479 by 1 pixels
# Shifting slice 1480 by 1 pixels
# Shifting slice 1481 by 1 pixels
# Shifting slice 1482 by 1 pixels
# Shifting slice 1483 by 1 pixels
# Shifting slice 1484 by 1 pixels
# Shifting slice 1485 by 1 pixels
# Shifting slice 1486 by 1 pixels
# Shifting slice 1487 by 1 pixels
# Shifting slice 1488 by 1 pixels
# Shifting slice 1489 by 1 pixels
# Shifting slice 1490 by 1 pixels
# Shifting slice 1491 by 1 pixels
# Shifting slice 1492 by 1 pixels
# Shifting slice 1493 by 1 pixels
# Shifting slice 1494 by 1 pixels
# Shifting slice 1495 by 1 pixels
# Shifting slice 1496 by 1 pixels
# Shifting slice 1497 by 1 pixels
# Shifting slice 1498 by 1 pixels
# Shifting slice 1499 by 1 pixels
# Shifting slice 1500 by 1 pixels
# Shifting slice 1501 by 1 pixels
# Shifting slice 1502 by 1 pixels
# Shifting slice 1503 by 1 pixels
# Shifting slice 1504 by 1 pixels
# Shifting slice 1505 by 1 pixels
# Shifting slice 1506 by 1 pixels
# Shifting slice 1507 by 1 pixels
# Shifting slice 1508 by 1 pixels
# Shifting slice 1509 by 1 pixels
# Shifting slice 1510 by 1 pixels
# Shifting slice 1511 by 1 pixels
# Shifting slice 1512 by 1 pixels
# Shifting slice 1513 by 1 pixels
# Shifting slice 1514 by 1 pixels
# Shifting slice 1515 by 1 pixels
# Shifting slice 1516 by 1 pixels
# Shifting slice 1517 by 1 pixels
# Shifting slice 1518 by 1 pixels
# Shifting slice 1519 by 1 pixels
# Shifting slice 1520 by 1 pixels
# Shifting slice 1521 by 1 pixels
# Shifting slice 1522 by 1 pixels
# Shifting slice 1523 by 1 pixels
# Shifting slice 1524 by 1 pixels
# Shifting slice 1525 by 1 pixels
# Shifting slice 1526 by 1 pixels
# Shifting slice 1527 by 1 pixels
# Shifting slice 1528 by 1 pixels
# Shifting slice 1529 by 1 pixels
# Shifting slice 1530 by 1 pixels
# Shifting slice 1531 by 1 pixels
# Shifting slice 1532 by 1 pixels
# Shifting slice 1533 by 1 pixels
# ...
# Shifting slice 89000 by 58 pixels
# Shifting slice 89001 by 58 pixels
# Shifting slice 89002 by 58 pixels
# Shifting slice 89003 by 58 pixels
# Shifting slice 89004 by 58 pixels
# Shifting slice 89005 by 58 pixels
# Shifting slice 89006 by 58 pixels
# Shifting slice 89007 by 58 pixels
# Shifting slice 89008 by 58 pixels
# Shifting slice 89009 by 58 pixels
# Shifting slice 89010 by 58 pixels
# Shifting slice 89011 by 58 pixels
# Shifting slice 89012 by 58 pixels
# Shifting slice 89013 by 58 pixels
# Shifting slice 89014 by 58 pixels
# Shifting slice 89015 by 58 pixels
# Shifting slice 89016 by 58 pixels
# Shifting slice 89017 by 58 pixels
# Shifting slice 89018 by 58 pixels
# Shifting slice 89019 by 58 pixels
# Shifting slice 89020 by 58 pixels
# Shifting slice 89021 by 58 pixels
# Shifting slice 89022 by 58 pixels
# Shifting slice 89023 by 58 pixels
# Shifting slice 89024 by 58 pixels
# Shifting slice 89025 by 58 pixels
# Shifting slice 89026 by 58 pixels
# Shifting slice 89027 by 58 pixels
# Shifting slice 89028 by 58 pixels
# Shifting slice 89029 by 58 pixels
# Shifting slice 89030 by 58 pixels
# Shifting slice 89031 by 58 pixels
# Shifting slice 89032 by 58 pixels
# Shifting slice 89033 by 58 pixels
# Shifting slice 89034 by 58 pixels
# Shifting slice 89035 by 58 pixels
# Shifting slice 89036 by 58 pixels
# Shifting slice 89037 by 58 pixels
# Shifting slice 89038 by 58 pixels
# Shifting slice 89039 by 58 pixels
# Shifting slice 89040 by 58 pixels
# Shifting slice 89041 by 58 pixels
# Shifting slice 89042 by 58 pixels
# Shifting slice 89043 by 58 pixels
# Shifting slice 89044 by 58 pixels
# Shifting slice 89045 by 58 pixels
# Shifting slice 89046 by 58 pixels
# Shifting slice 89047 by 58 pixels
# Shifting slice 89048 by 58 pixels
# Shifting slice 89049 by 58 pixels
# Shifting slice 89050 by 58 pixels
# Shifting slice 89051 by 58 pixels
# Shifting slice 89052 by 58 pixels
# Shifting slice 89053 by 58 pixels
# Shifting slice 89054 by 58 pixels
# Shifting slice 89055 by 58 pixels
# Shifting slice 89056 by 58 pixels
# Shifting slice 89057 by 58 pixels
# Shifting slice 89058 by 58 pixels
# Shifting slice 89059 by 58 pixels
# Shifting slice 89060 by 58 pixels
# Shifting slice 89061 by 58 pixels
# Shifting slice 89062 by 58 pixels
# Shifting slice 89063 by 58 pixels
# Shifting slice 89064 by 58 pixels
# Shifting slice 89065 by 58 pixels
# Shifting slice 89066 by 58 pixels
# Shifting slice 89067 by 58 pixels
# Shifting slice 89068 by 58 pixels
# Shifting slice 89069 by 58 pixels
# Shifting slice 89070 by 58 pixels
# Shifting slice 89071 by 58 pixels
# Shifting slice 89072 by 58 pixels
# Shifting slice 89073 by 58 pixels
# Shifting slice 89074 by 58 pixels
# Shifting slice 89075 by 58 pixels
# Shifting slice 89076 by 58 pixels
# Shifting slice 89077 by 58 pixels
# Shifting slice 89078 by 58 pixels
# Shifting slice 89079 by 58 pixels
# Shifting slice 89080 by 58 pixels
# Shifting slice 89081 by 58 pixels
# Shifting slice 89082 by 58 pixels
# Shifting slice 89083 by 58 pixels
# Shifting slice 89084 by 58 pixels
# Shifting slice 89085 by 58 pixels
# Shifting slice 89086 by 58 pixels
# Shifting slice 89087 by 58 pixels
# Shifting slice 89088 by 58 pixels
# Shifting slice 89089 by 58 pixels
# Shifting slice 89090 by 58 pixels
# Shifting slice 89091 by 58 pixels
# Shifting slice 89092 by 58 pixels
# Shifting slice 89093 by 58 pixels
# Shifting slice 89094 by 58 pixels
# Shifting slice 89095 by 58 pixels
# Shifting slice 89096 by 58 pixels
# Shifting slice 89097 by 58 pixels
# Shifting slice 89098 by 58 pixels
# Shifting slice 89099 by 58 pixels
# Shifting slice 89100 by 58 pixels
# Shifting slice 89101 by 58 pixels
# Shifting slice 89102 by 58 pixels
# Shifting slice 89103 by 58 pixels
# Shifting slice 89104 by 58 pixels
# Shifting slice 89105 by 58 pixels
# Shifting slice 89106 by 58 pixels
# Shifting slice 89107 by 58 pixels
# Shifting slice 89108 by 58 pixels
# Shifting slice 89109 by 58 pixels
# Shifting slice 89110 by 58 pixels
# Shifting slice 89111 by 58 pixels
# Shifting slice 89112 by 58 pixels
# Shifting slice 89113 by 58 pixels
# Shifting slice 89114 by 58 pixels
# Shifting slice 89115 by 58 pixels
# Shifting slice 89116 by 58 pixels
# Shifting slice 89117 by 58 pixels
# Shifting slice 89118 by 58 pixels
# Shifting slice 89119 by 58 pixels
# Shifting slice 89120 by 58 pixels
# Shifting slice 89121 by 58 pixels
# Shifting slice 89122 by 58 pixels
# Shifting slice 89123 by 58 pixels
# Shifting slice 89124 by 58 pixels
# Shifting slice 89125 by 58 pixels
# Shifting slice 89126 by 58 pixels
# Shifting slice 89127 by 58 pixels
# Shifting slice 89128 by 58 pixels
# Shifting slice 89129 by 58 pixels
# Shifting slice 89130 by 58 pixels
# Shifting slice 89131 by 58 pixels
# Shifting slice 89132 by 58 pixels
# Shifting slice 89133 by 58 pixels
# Shifting slice 89134 by 58 pixels
# Shifting slice 89135 by 58 pixels
# Shifting slice 89136 by 58 pixels
# Shifting slice 89137 by 58 pixels
# Shifting slice 89138 by 58 pixels
# Shifting slice 89139 by 58 pixels
# Shifting slice 89140 by 58 pixels
# Shifting slice 89141 by 58 pixels
# Shifting slice 89142 by 58 pixels
# Shifting slice 89143 by 58 pixels
# Shifting slice 89144 by 58 pixels
# Shifting slice 89145 by 58 pixels
# Shifting slice 89146 by 58 pixels
# Shifting slice 89147 by 58 pixels
# Shifting slice 89148 by 58 pixels
# Shifting slice 89149 by 58 pixels
# Shifting slice 89150 by 58 pixels
# Shifting slice 89151 by 58 pixels
# Shifting slice 89152 by 58 pixels
# Shifting slice 89153 by 58 pixels
# Shifting slice 89154 by 58 pixels
# Shifting slice 89155 by 58 pixels
# Shifting slice 89156 by 58 pixels
# Shifting slice 89157 by 58 pixels
# Shifting slice 89158 by 58 pixels
# Shifting slice 89159 by 58 pixels
# Shifting slice 89160 by 58 pixels
# Shifting slice 89161 by 58 pixels
# Shifting slice 89162 by 58 pixels
# Shifting slice 89163 by 58 pixels
# Shifting slice 89164 by 58 pixels
# Shifting slice 89165 by 58 pixels
# Shifting slice 89166 by 58 pixels
# Shifting slice 89167 by 58 pixels
# Shifting slice 89168 by 58 pixels
# Shifting slice 89169 by 58 pixels
# Shifting slice 89170 by 58 pixels
# Shifting slice 89171 by 58 pixels
# Shifting slice 89172 by 58 pixels
# Shifting slice 89173 by 58 pixels
# Shifting slice 89174 by 58 pixels
# Shifting slice 89175 by 58 pixels
# Shifting slice 89176 by 58 pixels
# Shifting slice 89177 by 58 pixels
# Shifting slice 89178 by 58 pixels
# Shifting slice 89179 by 58 pixels
# Shifting slice 89180 by 58 pixels
# Shifting slice 89181 by 58 pixels
# Shifting slice 89182 by 58 pixels
# Shifting slice 89183 by 58 pixels
# Shifting slice 89184 by 58 pixels
# Shifting slice 89185 by 58 pixels
# Shifting slice 89186 by 58 pixels
# Shifting slice 89187 by 58 pixels
# Shifting slice 89188 by 58 pixels
# Shifting slice 89189 by 58 pixels
# Shifting slice 89190 by 58 pixels
# Shifting slice 89191 by 58 pixels
# Shifting slice 89192 by 58 pixels
# Shifting slice 89193 by 58 pixels
# Shifting slice 89194 by 58 pixels
# Shifting slice 89195 by 58 pixels
# Shifting slice 89196 by 58 pixels
# Shifting slice 89197 by 58 pixels
# Shifting slice 89198 by 58 pixels
# Shifting slice 89199 by 58 pixels
# Shifting slice 89200 by 58 pixels
# Shifting slice 89201 by 58 pixels
# Shifting slice 89202 by 58 pixels
# Shifting slice 89203 by 58 pixels
# Shifting slice 89204 by 58 pixels
# Shifting slice 89205 by 58 pixels
# Shifting slice 89206 by 58 pixels
# Shifting slice 89207 by 58 pixels
# Shifting slice 89208 by 58 pixels
# Shifting slice 89209 by 58 pixels
# Shifting slice 89210 by 58 pixels
# Shifting slice 89211 by 58 pixels
# Shifting slice 89212 by 58 pixels
# Shifting slice 89213 by 58 pixels
# Shifting slice 89214 by 58 pixels
# Shifting slice 89215 by 58 pixels
# Shifting slice 89216 by 58 pixels
# Shifting slice 89217 by 58 pixels
# Shifting slice 89218 by 58 pixels
# Shifting slice 89219 by 58 pixels
# Shifting slice 89220 by 58 pixels
# Shifting slice 89221 by 58 pixels
# Shifting slice 89222 by 58 pixels
# Shifting slice 89223 by 58 pixels
# Shifting slice 89224 by 58 pixels
# Shifting slice 89225 by 58 pixels
# Shifting slice 89226 by 58 pixels
# Shifting slice 89227 by 58 pixels
# Shifting slice 89228 by 58 pixels
# Shifting slice 89229 by 58 pixels
# Shifting slice 89230 by 58 pixels
# Shifting slice 89231 by 58 pixels
# Shifting slice 89232 by 58 pixels
# Shifting slice 89233 by 58 pixels
# Shifting slice 89234 by 58 pixels
# Shifting slice 89235 by 58 pixels
# Shifting slice 89236 by 58 pixels
# Shifting slice 89237 by 58 pixels
# Shifting slice 89238 by 58 pixels
# Shifting slice 89239 by 58 pixels
# Shifting slice 89240 by 58 pixels
# Shifting slice 89241 by 58 pixels
# Shifting slice 89242 by 58 pixels
# Shifting slice 89243 by 58 pixels
# Shifting slice 89244 by 58 pixels
# Shifting slice 89245 by 58 pixels
# Shifting slice 89246 by 58 pixels
# Shifting slice 89247 by 58 pixels
# Shifting slice 89248 by 58 pixels
# Shifting slice 89249 by 58 pixels
# Shifting slice 89250 by 58 pixels
# Shifting slice 89251 by 58 pixels
# Shifting slice 89252 by 58 pixels
# Shifting slice 89253 by 58 pixels
# Shifting slice 89254 by 58 pixels
# Shifting slice 89255 by 58 pixels
# Shifting slice 89256 by 58 pixels
# Shifting slice 89257 by 58 pixels
# Shifting slice 89258 by 58 pixels
# Shifting slice 89259 by 58 pixels
# Shifting slice 89260 by 58 pixels
# Shifting slice 89261 by 58 pixels
# Shifting slice 89262 by 58 pixels
# Shifting slice 89263 by 58 pixels
# Shifting slice 89264 by 58 pixels
# Shifting slice 89265 by 58 pixels
# Shifting slice 89266 by 58 pixels
# Shifting slice 89267 by 58 pixels
# Shifting slice 89268 by 58 pixels
# Shifting slice 89269 by 58 pixels
# Shifting slice 89270 by 58 pixels
# Shifting slice 89271 by 58 pixels
# Shifting slice 89272 by 58 pixels
# Shifting slice 89273 by 58 pixels
# Shifting slice 89274 by 58 pixels
# Shifting slice 89275 by 58 pixels
# Shifting slice 89276 by 58 pixels
# Shifting slice 89277 by 58 pixels
# Shifting slice 89278 by 58 pixels
# Shifting slice 89279 by 58 pixels
# Shifting slice 89280 by 58 pixels
# Shifting slice 89281 by 58 pixels
# Shifting slice 89282 by 58 pixels
# Shifting slice 89283 by 58 pixels
# Shifting slice 89284 by 58 pixels
# Shifting slice 89285 by 58 pixels
# Shifting slice 89286 by 58 pixels
# Shifting slice 89287 by 58 pixels
# Shifting slice 89288 by 58 pixels
# Shifting slice 89289 by 58 pixels
# Shifting slice 89290 by 58 pixels
# Shifting slice 89291 by 58 pixels
# Shifting slice 89292 by 58 pixels
# Shifting slice 89293 by 58 pixels
# Shifting slice 89294 by 58 pixels
# Shifting slice 89295 by 58 pixels
# Shifting slice 89296 by 58 pixels
# Shifting slice 89297 by 58 pixels
# Shifting slice 89298 by 58 pixels
# Shifting slice 89299 by 58 pixels
# Shifting slice 89300 by 58 pixels
# Shifting slice 89301 by 58 pixels
# Shifting slice 89302 by 58 pixels
# Shifting slice 89303 by 58 pixels
# Shifting slice 89304 by 58 pixels
# Shifting slice 89305 by 58 pixels
# Shifting slice 89306 by 58 pixels
# Shifting slice 89307 by 58 pixels
# Shifting slice 89308 by 58 pixels
# Shifting slice 89309 by 58 pixels
# Shifting slice 89310 by 58 pixels
# Shifting slice 89311 by 58 pixels
# Shifting slice 89312 by 58 pixels
# Shifting slice 89313 by 58 pixels
# Shifting slice 89314 by 58 pixels
# Shifting slice 89315 by 58 pixels
# Shifting slice 89316 by 58 pixels
# Shifting slice 89317 by 58 pixels
# Shifting slice 89318 by 58 pixels
# Shifting slice 89319 by 58 pixels
# Shifting slice 89320 by 58 pixels
# Shifting slice 89321 by 58 pixels
# Shifting slice 89322 by 58 pixels
# Shifting slice 89323 by 58 pixels
# Shifting slice 89324 by 58 pixels
# Shifting slice 89325 by 58 pixels
# Shifting slice 89326 by 58 pixels
# Shifting slice 89327 by 58 pixels
# Shifting slice 89328 by 58 pixels
# Shifting slice 89329 by 58 pixels
# Shifting slice 89330 by 58 pixels
# Shifting slice 89331 by 58 pixels
# Shifting slice 89332 by 58 pixels
# Shifting slice 89333 by 58 pixels
# Shifting slice 89334 by 58 pixels
# Shifting slice 89335 by 58 pixels
# Shifting slice 89336 by 58 pixels
# Shifting slice 89337 by 58 pixels
# Shifting slice 89338 by 58 pixels
# Shifting slice 89339 by 58 pixels
# Shifting slice 89340 by 58 pixels
# Shifting slice 89341 by 58 pixels
# Shifting slice 89342 by 58 pixels
# Shifting slice 89343 by 58 pixels
# Shifting slice 89344 by 58 pixels
# Shifting slice 89345 by 58 pixels
# Shifting slice 89346 by 58 pixels
# Shifting slice 89347 by 58 pixels
# Shifting slice 89348 by 58 pixels
# Shifting slice 89349 by 58 pixels
# Shifting slice 89350 by 58 pixels
# Shifting slice 89351 by 58 pixels
# Shifting slice 89352 by 58 pixels
# Shifting slice 89353 by 58 pixels
# Shifting slice 89354 by 58 pixels
# Shifting slice 89355 by 58 pixels
# Shifting slice 89356 by 58 pixels
# Shifting slice 89357 by 58 pixels
# Shifting slice 89358 by 58 pixels
# Shifting slice 89359 by 58 pixels
# Shifting slice 89360 by 58 pixels
# Shifting slice 89361 by 58 pixels
# Shifting slice 89362 by 58 pixels
# Shifting slice 89363 by 58 pixels
# Shifting slice 89364 by 58 pixels
# Shifting slice 89365 by 58 pixels
# Shifting slice 89366 by 58 pixels
# Shifting slice 89367 by 58 pixels
# Shifting slice 89368 by 58 pixels
# Shifting slice 89369 by 58 pixels
# Shifting slice 89370 by 58 pixels
# Shifting slice 89371 by 58 pixels
# Shifting slice 89372 by 58 pixels
# Shifting slice 89373 by 58 pixels
# Shifting slice 89374 by 58 pixels
# Shifting slice 89375 by 58 pixels
# Shifting slice 89376 by 58 pixels
# Shifting slice 89377 by 58 pixels
# Shifting slice 89378 by 58 pixels
# Shifting slice 89379 by 58 pixels
# Shifting slice 89380 by 58 pixels
# Shifting slice 89381 by 58 pixels
# Shifting slice 89382 by 58 pixels
# Shifting slice 89383 by 58 pixels
# Shifting slice 89384 by 58 pixels
# Shifting slice 89385 by 58 pixels
# Shifting slice 89386 by 58 pixels
# Shifting slice 89387 by 58 pixels
# Shifting slice 89388 by 58 pixels
# Shifting slice 89389 by 58 pixels
# Shifting slice 89390 by 58 pixels
# Shifting slice 89391 by 58 pixels
# Shifting slice 89392 by 58 pixels
# Shifting slice 89393 by 58 pixels
# Shifting slice 89394 by 58 pixels
# Shifting slice 89395 by 58 pixels
# Shifting slice 89396 by 58 pixels
# Shifting slice 89397 by 58 pixels
# Shifting slice 89398 by 58 pixels
# Shifting slice 89399 by 58 pixels
# Shifting slice 89400 by 58 pixels
# Shifting slice 89401 by 58 pixels
# Shifting slice 89402 by 58 pixels
# Shifting slice 89403 by 58 pixels
# Shifting slice 89404 by 58 pixels
# Shifting slice 89405 by 58 pixels
# Shifting slice 89406 by 58 pixels
# Shifting slice 89407 by 58 pixels
# Shifting slice 89408 by 58 pixels
# Shifting slice 89409 by 58 pixels
# Shifting slice 89410 by 58 pixels
# Shifting slice 89411 by 58 pixels
# Shifting slice 89412 by 58 pixels
# Shifting slice 89413 by 58 pixels
# Shifting slice 89414 by 58 pixels
# Shifting slice 89415 by 58 pixels
# Shifting slice 89416 by 58 pixels
# Shifting slice 89417 by 58 pixels
# Shifting slice 89418 by 58 pixels
# Shifting slice 89419 by 58 pixels
# Shifting slice 89420 by 58 pixels
# Shifting slice 89421 by 58 pixels
# Shifting slice 89422 by 58 pixels
# Shifting slice 89423 by 58 pixels
# Shifting slice 89424 by 58 pixels
# Shifting slice 89425 by 58 pixels
# Shifting slice 89426 by 58 pixels
# Shifting slice 89427 by 58 pixels
# Shifting slice 89428 by 58 pixels
# Shifting slice 89429 by 58 pixels
# Shifting slice 89430 by 58 pixels
# Shifting slice 89431 by 58 pixels
# Shifting slice 89432 by 58 pixels
# Shifting slice 89433 by 58 pixels
# Shifting slice 89434 by 58 pixels
# Shifting slice 89435 by 58 pixels
# Shifting slice 89436 by 58 pixels
# Shifting slice 89437 by 58 pixels
# Shifting slice 89438 by 58 pixels
# Shifting slice 89439 by 58 pixels
# Shifting slice 89440 by 58 pixels
# Shifting slice 89441 by 58 pixels
# Shifting slice 89442 by 58 pixels
# Shifting slice 89443 by 58 pixels
# Shifting slice 89444 by 58 pixels
# Shifting slice 89445 by 58 pixels
# Shifting slice 89446 by 58 pixels
# Shifting slice 89447 by 58 pixels
# Shifting slice 89448 by 58 pixels
# Shifting slice 89449 by 58 pixels
# Shifting slice 89450 by 58 pixels
# Shifting slice 89451 by 58 pixels
# Shifting slice 89452 by 58 pixels
# Shifting slice 89453 by 58 pixels
# Shifting slice 89454 by 58 pixels
# Shifting slice 89455 by 58 pixels
# Shifting slice 89456 by 58 pixels
# Shifting slice 89457 by 58 pixels
# Shifting slice 89458 by 58 pixels
# Shifting slice 89459 by 58 pixels
# Shifting slice 89460 by 58 pixels
# Shifting slice 89461 by 58 pixels
# Shifting slice 89462 by 58 pixels
# Shifting slice 89463 by 58 pixels
# Shifting slice 89464 by 58 pixels
# Shifting slice 89465 by 58 pixels
# Shifting slice 89466 by 58 pixels
# Shifting slice 89467 by 58 pixels
# Shifting slice 89468 by 58 pixels
# Shifting slice 89469 by 58 pixels

# %%
import math
import os
import shutil
import time
import tifffile as t
import numpy as np
from concurrent.futures import ThreadPoolExecutor
import psutil

cpu_logical_count = psutil.cpu_count(logical=True)
cpu_physical_count = psutil.cpu_count(logical=False)

print(f"Logical CPUs (threads): {cpu_logical_count}")
print(f"Physical CPUs (cores): {cpu_physical_count}")

cpu_count = os.cpu_count()
print(f"Number of CPU cores: {cpu_count}")

# Define the function to process a single slice (for concurrent processing)
def process_slice(i):
    _slice = vol[i, :, :]
    shift_size = math.ceil(2 * i * math.sin(angle_radians / 2))
    # print(f"Shifting slice {i} by {shift_size} pixels (concurrent)")
    shifted_slice = np.roll(_slice, -shift_size, axis=0)
    t.imwrite(f"./shifted_concurrent/shifted_slice_{i}.tif", shifted_slice)

# Create the 'shifted' and 'shifted_concurrent' folders if they don't exist
shifted_folder = "./shifted"
shifted_concurrent_folder = "./shifted_concurrent"
os.makedirs(shifted_folder, exist_ok=True)
os.makedirs(shifted_concurrent_folder, exist_ok=True)

# # Time the sequential processing
# start_time_seq = time.time()
iterator = range(vol.shape[0]) if direction == "downwards" else reversed(range(vol.shape[0]))
# for i in iterator:
#     _slice = vol[i, :, :]
#     shift_size = math.ceil(2 * i * math.sin(angle_radians / 2))
#     # print(f"Shifting slice {i} by {shift_size} pixels (sequential)")
#     shifted_slice = np.roll(_slice, -shift_size, axis=0)
#     t.imwrite(f"{shifted_folder}/shifted_slice_{i}.tif", shifted_slice)
# end_time_seq = time.time()
# print(f"Sequential processing time: {end_time_seq - start_time_seq} seconds.")

# Remove the 'shifted' folder
shutil.rmtree(shifted_folder)

# Time the concurrent processing
start_time_concurrent = time.time()
with ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:  # Adjust max_workers as needed
    executor.map(process_slice, iterator)
end_time_concurrent = time.time()
print(f"Concurrent processing time: {end_time_concurrent - start_time_concurrent} seconds.")
# Out:
# Logical CPUs (threads): 20
# Physical CPUs (cores): 12
# Number of CPU cores: 20

# %%
# Out:
# Sequential processing time: 686.0818467140198 seconds.
# Concurrent processing time: 614.9080040454865 seconds.
